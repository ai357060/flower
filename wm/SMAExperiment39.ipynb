# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
dictList = []
colFeat = []
keyList = []

# maKey  = [3,5,7,35,40,45,50,60,80,100,120,130,140,150,160,170]
atrKey = [10,20]
# srsKey = [0]
rsiKey = [15]

# maDict   = ma2(prices, maKey,3,5,7)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
rsiDict = rsi(prices,rsiKey)

# dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 
dictList.append(rsiDict.df); colFeat.append('rsi'); keyList.append(rsiKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.052002

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close     volume  atr10atr_prev  atr20atr_prev  rsi15rsi1  \
# 4748  0.73781  0.74102   96688.34       0.005612       0.006553  62.884996
# 4749  0.74074  0.74715   93228.11       0.005672       0.006606  61.728938
# 4750  0.74647  0.75144   94912.55       0.005927       0.006687  67.225160
# 4751  0.74581  0.74655   97404.62       0.005828       0.006611  70.411398
# 4752  0.74533  0.74631  123259.25       0.006149       0.006588  62.938811
#
#       rsi15rsi_prev  rsi15rsidiffseq_prev
# 4748      62.884996                   5.0
# 4749      61.728938                  -1.0
# 4750      67.225160                   1.0
# 4751      70.411398                   2.0
# 4752      62.938811                  -1.0

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr20atr_prev'
sl = [0.5,0.6,0.65,0.7,0.75,0.8,0.85,0.9,1]
tp = [0.5,0.6,0.7,0.75,0.8,0.85,0.9,1]
tsl = [0]
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp+[100],tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.5 : 0.5 : 0 : -6  open: 0
# 0.5 : 0.6 : 0 : -12  open: 0
# 0.5 : 0.7 : 0 : -12  open: 0
# 0.5 : 0.75 : 0 : -13  open: 1
# 0.5 : 0.8 : 0 : -13  open: 1
# 0.5 : 0.85 : 0 : -13  open: 1
# 0.5 : 0.9 : 0 : -13  open: 1
# 0.5 : 1 : 0 : -14  open: 1
# 0.5 : 100 : 0 : -15  open: 1
# 0.6 : 0.5 : 0 : -8  open: 0
# 0.6 : 0.6 : 0 : -12  open: 0
# 0.6 : 0.7 : 0 : -12  open: 0
# 0.6 : 0.75 : 0 : -13  open: 1
# 0.6 : 0.8 : 0 : -13  open: 1
# 0.6 : 0.85 : 0 : -13  open: 1
# 0.6 : 0.9 : 0 : -13  open: 1
# 0.6 : 1 : 0 : -14  open: 1
# 0.6 : 100 : 0 : -22  open: 1
# 0.65 : 0.5 : 0 : -8  open: 0
# 0.65 : 0.6 : 0 : -12  open: 0
# 0.65 : 0.7 : 0 : -12  open: 0
# 0.65 : 0.75 : 0 : -13  open: 1
# 0.65 : 0.8 : 0 : -13  open: 1
# 0.65 : 0.85 : 0 : -13  open: 1
# 0.65 : 0.9 : 0 : -13  open: 1
# 0.65 : 1 : 0 : -16  open: 1
# 0.65 : 100 : 0 : -22  open: 1
# 0.7 : 0.5 : 0 : -8  open: 0
# 0.7 : 0.6 : 0 : -12  open: 0
# 0.7 : 0.7 : 0 : -12  open: 0
# 0.7 : 0.75 : 0 : -13  open: 1
# 0.7 : 0.8 : 0 : -13  open: 1
# 0.7 : 0.85 : 0 : -17  open: 1
# 0.7 : 0.9 : 0 : -17  open: 1
# 0.7 : 1 : 0 : -17  open: 1
# 0.7 : 100 : 0 : -28  open: 1
# 0.75 : 0.5 : 0 : -10  open: 0
# 0.75 : 0.6 : 0 : -12  open: 0
# 0.75 : 0.7 : 0 : -12  open: 0
# 0.75 : 0.75 : 0 : -13  open: 1
# 0.75 : 0.8 : 0 : -13  open: 1
# 0.75 : 0.85 : 0 : -17  open: 1
# 0.75 : 0.9 : 0 : -17  open: 1
# 0.75 : 1 : 0 : -17  open: 1
# 0.75 : 100 : 0 : -28  open: 1
# 0.8 : 0.5 : 0 : -10  open: 0
# 0.8 : 0.6 : 0 : -12  open: 0
# 0.8 : 0.7 : 0 : -12  open: 0
# 0.8 : 0.75 : 0 : -13  open: 1
# 0.8 : 0.8 : 0 : -13  open: 1
# 0.8 : 0.85 : 0 : -17  open: 1
# 0.8 : 0.9 : 0 : -17  open: 1
# 0.8 : 1 : 0 : -17  open: 1
# 0.8 : 100 : 0 : -28  open: 1
# 0.85 : 0.5 : 0 : -10  open: 0
# 0.85 : 0.6 : 0 : -13  open: 0
# 0.85 : 0.7 : 0 : -13  open: 0
# 0.85 : 0.75 : 0 : -14  open: 1
# 0.85 : 0.8 : 0 : -14  open: 1
# 0.85 : 0.85 : 0 : -17  open: 1
# 0.85 : 0.9 : 0 : -17  open: 1
# 0.85 : 1 : 0 : -17  open: 1
# 0.85 : 100 : 0 : -28  open: 1
# 0.9 : 0.5 : 0 : -10  open: 0
# 0.9 : 0.6 : 0 : -13  open: 0
# 0.9 : 0.7 : 0 : -16  open: 0
# 0.9 : 0.75 : 0 : -16  open: 1
# 0.9 : 0.8 : 0 : -16  open: 1
# 0.9 : 0.85 : 0 : -17  open: 1
# 0.9 : 0.9 : 0 : -17  open: 1
# 0.9 : 1 : 0 : -20  open: 1
# 0.9 : 100 : 0 : -31  open: 1
# 1 : 0.5 : 0 : -11  open: 0
# 1 : 0.6 : 0 : -16  open: 1
# 1 : 0.7 : 0 : -16  open: 1
# 1 : 0.75 : 0 : -16  open: 2
# 1 : 0.8 : 0 : -16  open: 2
# 1 : 0.85 : 0 : -18  open: 2
# 1 : 0.9 : 0 : -18  open: 2
# 1 : 1 : 0 : -20  open: 2
# 1 : 100 : 0 : -56  open: 16
# 0:00:42.597110

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True,'39')
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#     id  year  month  day                date  weekday     open     high  \
# 20  20  2003      9    1 2003-09-01 21:00:00        0  0.64652  0.64805
# 21  21  2003      9    2 2003-09-02 21:00:00        1  0.64514  0.64595
#
#         low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 20  0.64380  0.64533  ...  0.642956    0.650084        21.0          -1.0
# 21  0.63503  0.63611  ...  0.641694    0.648586        21.0          -1.0
#
#     closeprice  tpcloseprice  slindex  slprice   profit  profit1
# 20    0.642956          -1.0     21.0  0.63503 -35.6400       -1
# 21    0.641694          -1.0     21.0  0.63503 -34.4625       -1
#
# [2 rows x 35 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    runstats_ma_v36(alltrades,'rsi'+str(rsiKey[0])+'rsidiffseq_prev','rsi'+str(rsiKey[0])+'rsi_prev', atrperiod,sl,tp,tsl,'x1')
    runstats_ma_v36(alltrades,'rsi'+str(rsiKey[0])+'rsidiffseq_prev','rsi'+str(rsiKey[0])+'rsi_prev', atrperiod,sl,[100],[0],'x2')
# Out:
# ma_36_2003_2021_1_atr20atr_prev_x1
# allexecs:  83160
# ____progress:   0.74 %
# elapsed:        0:00:30.029835
# last run:       0:00:30.030835
# remaining:      1:07:10.589805
# estimated end:  2021-12-19 19:04:37.403018
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4864/2344357037.py in <module>
#       4 for i in [20]:
#       5     atrperiod = 'atr'+str(i)+'atr_prev'
# ----> 6     runstats_ma_v36(alltrades,'rsi'+str(rsiKey[0])+'rsidiffseq_prev','rsi'+str(rsiKey[0])+'rsi_prev', atrperiod,sl,tp,tsl,'x1')
#       7     runstats_ma_v36(alltrades,'rsi'+str(rsiKey[0])+'rsidiffseq_prev','rsi'+str(rsiKey[0])+'rsi_prev', atrperiod,sl,[100],[0],'x2')
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v36(alltrades, a, b, atr, sl, tp, tsl, ff)
#    3128     conf['filename'] =    'ma_36_2003_2021_1_'+atr+'_'+ff
#    3129     print(conf['filename'])
# -> 3130     stathyperparams2(alltrades,params,conf)
#    3131     return
#    3132
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1253     seq['lastrun'] = datetime.now()
#    1254     stats = stats.values.tolist()
# -> 1255     stats = execstats2_r(trades,stats,params,seq)
#    1256     stats = pd.DataFrame(stats)
#    1257
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1334                 if (ito>ifrom):
#    1335                     seq[key] = [imode,ifrom,ito]
# -> 1336                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1337
#    1338     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1337
#    1338     else:
# -> 1339         stats = execstats2(trades,stats,params,seq)
#    1340     return stats
#    1341
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1346     else:
#    1347         seq['execs'] = seq['execs'] + 1
# -> 1348         df = calculatestats2(trades,params,seq)
#    1349         if (not df is None):
#    1350             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1371     timedump('1')
#    1372
# -> 1373     stats0 = trades.copy()
#    1374 #     for kk in params.keys():
#    1375 #         imode = seq[kk][0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5931         dtype: object
#    5932         """
# -> 5933         data = self._mgr.copy(deep=deep)
#    5934         self._clear_item_cache()
#    5935         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     597             new_axes = list(self.axes)
#     598
# --> 599         res = self.apply("copy", deep=deep)
#     600         res.axes = new_axes
#     601
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     648         values = self.values
#     649         if deep:
# --> 650             values = values.copy()
#     651         return self.make_block_same_class(values)
#     652
#
# KeyboardInterrupt:
