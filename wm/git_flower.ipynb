# %%
#mount
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)

import sys
sys.path.append("/content/gdrive/My Drive/Projects/flower")
# Out:
# Mounted at /content/gdrive

# %%
#git clone
# %cd "/content/gdrive/My Drive/Projects"
# !git clone https://github.com/ai357060/flower.git

# %%
#git fetch
#%cd "/content/gdrive/My Drive/Projects/flower/wm"
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git fetch --all
# !git reset --hard origin/master

# %%
#git pull
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git pull https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# From https://github.com/ai357060/flower
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/flower.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/flower"
    sys.path.append(root_dir)
#    %cd "/content/gdrive/My Drive/Projects/flower/wm"
    # !git pull

# %%
#git push
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git commit -a -m "c20240201_3"
# !git push https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@77d808fe771e.(none)')
# Everything up-to-date

# %%
# !git add "wm/git_flower.ipynb"
