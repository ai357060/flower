# %%
#mount
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)

import sys
sys.path.append("/content/gdrive/My Drive/Projects/flower")

# %%
#git clone
# %cd "/content/gdrive/My Drive/Projects"
# !git clone https://github.com/ai357060/flower.git

# %%
#git fetch
#%cd "/content/gdrive/My Drive/Projects/flower/wm"
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git fetch --all
# !git reset --hard origin/master

# %%
#git pull
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git pull https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# From https://github.com/ai357060/flower
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
#git push
#https://github.com/settings/tokens/new
# !git config --global user.email "ai357060@gmail.com"
# !git config --global user.name "ai357060"
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git add .
# !git commit -a -m "c20240225_1"
# !git push https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# [master f395783] c20240225_1
#  33 files changed, 79659 insertions(+), 4 deletions(-)
#  create mode 100644 Data/acp_d.csv
#  create mode 100644 Data/acp_w.csv
#  create mode 100644 Data/ale_d.csv
#  create mode 100644 Data/ale_w.csv
#  create mode 100644 Data/cdr_d.csv
#  create mode 100644 Data/cdr_w.csv
#  create mode 100644 Data/cps_d.csv
#  create mode 100644 Data/cps_w.csv
#  create mode 100644 Data/dnp_d.csv
#  create mode 100644 Data/dnp_w.csv
#  create mode 100644 Data/jsw_d.csv
#  create mode 100644 Data/jsw_w.csv
#  create mode 100644 Data/kgh_d.csv
#  create mode 100644 Data/kgh_w.csv
#  create mode 100644 Data/kru_d.csv
#  create mode 100644 Data/kru_w.csv
#  create mode 100644 Data/kty_d.csv
#  create mode 100644 Data/kty_w.csv
#  create mode 100644 Data/lpp_d.csv
#  create mode 100644 Data/lpp_w.csv
#  create mode 100644 Data/opl_d.csv
#  create mode 100644 Data/opl_w.csv
#  create mode 100644 Data/pco_d.csv
#  create mode 100644 Data/pco_w.csv
#  create mode 100644 Data/pge_d.csv
#  create mode 100644 Data/pge_w.csv
#  create mode 100644 Data/pzu_d.csv
#  create mode 100644 Data/pzu_w.csv
#  create mode 100644 Data/san_d.csv
#  create mode 100644 Data/san_w.csv
#  rewrite Data/stats.csv (80%)
#  rewrite wm/aw01.ipynb (91%)
# Enumerating objects: 43, done.
# Counting objects: 100% (43/43), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (37/37), done.
# Writing objects: 100% (37/37), 2.08 MiB | 2.51 MiB/s, done.
# Total 37 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/ai357060/flower.git
#    c9e7b86..f395783  master -> master

# %%
# !git add "wm/git_flower.ipynb"

# %%
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git rm -r -f "wm/__pycache__"
# !git rm -r -f "Data"
