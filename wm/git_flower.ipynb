# %%
#mount
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)

import sys
sys.path.append("/content/gdrive/My Drive/Projects/flower")
# Out:
# Mounted at /content/gdrive

# %%
#git clone
# %cd "/content/gdrive/My Drive/Projects"
# !git clone https://github.com/ai357060/flower.git

# %%
#git fetch
#%cd "/content/gdrive/My Drive/Projects/flower/wm"
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git fetch --all
# !git reset --hard origin/master

# %%
#git pull
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git pull https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# From https://github.com/ai357060/flower
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
#git push
#https://github.com/settings/tokens
# !git config --global user.email "ai357060@gmail.com"
# !git config --global user.name "ai357060"
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git add .
# !git commit -a -m "c20240324_1"
# !git push https://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@github.com/ai357060/flower.git
# Out:
# /content/gdrive/My Drive/Projects/flower
# [master 5c7a400] c20240324_1
#  5 files changed, 27829 insertions(+), 2192 deletions(-)
#  rewrite Data/masterFrame.csv (92%)
#  create mode 100644 Data/stats_gpw_w.csv
#  rewrite wm/aw02.ipynb (96%)
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 1.40 MiB | 2.02 MiB/s, done.
# Total 9 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# remote: error: GH013: Repository rule violations found for refs/heads/master.
# remote: Review all repository rules at http://github.com/ai357060/flower/rules?ref=refs%2Fheads%2Fmaster
# remote:
# remote: - GITHUB PUSH PROTECTION
# remote:   ——————————————————————————————————————————————————————
# remote:    Resolve the following secrets before pushing again.
# remote:
# remote:    (?) Learn how to resolve a blocked push
# remote:    https://docs.github.com/code-security/secret-scanning/pushing-a-branch-blocked-by-push-protection
# remote:
# remote:    (?) This repository does not have Secret Scanning enabled, but is eligible. Enable Secret Scanning to view and manage detected secrets.
# remote:    Visit the repository settings page, https://github.com/ai357060/flower/settings/security_analysis
# remote:
# remote:
# remote:
# remote:   —— GitHub Personal Access Token ——————————————————————
# remote:    locations:
# remote:      - commit: 5c7a400027f03a6c7891cfb20c6e713dd573020e
# remote:        path: wm/git_flower.ipynb:1
# remote:
# remote:    (?) To push, remove secret from commit(s) or follow this URL to allow the secret.
# remote:    https://github.com/ai357060/flower/security/secret-scanning/unblock-secret/2e9CzJFE5s13nHDTcUeutvg5OBX
# remote:
# To https://github.com/ai357060/flower.git
#  ! [remote rejected] master -> master (push declined due to repository rule violations)
# error: failed to push some refs to 'https://github.com/ai357060/flower.git'

# %%
# !git add "wm/git_flower.ipynb"

# %%
# %cd "/content/gdrive/My Drive/Projects/flower"
# !git rm -r -f "wm/__pycache__"
# !git rm -r -f "Data"
