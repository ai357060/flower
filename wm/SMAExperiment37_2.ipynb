# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [3,5,7,35,40,45,50,60,80,100,120,130,140,150,160,170]
atrKey = [15]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma2(prices, maKey,3,5,7)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.656035

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]
# Out:
# C:\Users\piotrek\AppData\Local\Temp/ipykernel_5860/3922565144.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma160SMAvs5_prev  ma160SMAvs7_prev  \
# 4748  0.73781  0.74102  ...         -0.014523         -0.016605
# 4749  0.74074  0.74715  ...         -0.013045         -0.015018
# 4750  0.74647  0.75144  ...         -0.010427         -0.012490
# 4751  0.74581  0.74655  ...         -0.007544         -0.009915
# 4752  0.74533  0.74631  ...         -0.006325         -0.008038
#
#       ma160SMAdiffseq_prev  ma170SMA_prev  ma170SMAdiffdiff_prev  \
# 4748                    -5       0.754232              -0.000058
# 4749                    -5       0.753936              -0.000032
# 4750                    -5       0.753678               0.000038
# 4751                    -5       0.753412              -0.000008
# 4752                    -5       0.753174               0.000027
#
#       ma170SMAvs3_prev  ma170SMAvs5_prev  ma170SMAvs7_prev  \
# 4748         -0.013928         -0.016212         -0.018293
# 4749         -0.012529         -0.014586         -0.016559
# 4750         -0.010375         -0.011862         -0.013925
# 4751         -0.006876         -0.008850         -0.011221
# 4752         -0.004794         -0.007594         -0.009307
#
#       ma170SMAdiffseq_prev  atr15atr_prev
# 4748                    -5       0.006367
# 4749                    -5       0.006464
# 4750                    -5       0.006411
# 4751                    -5       0.006169
# 4752                    -5       0.006184
#
# [5 rows x 108 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr15atr_prev'
sl = [0.6,0.65,0.7,0.75,0.8,0.85,0.9]
tp = [0.7,0.75,0.8,0.85,0.9]
tsl = [0]
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp+[100],tsl,2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.6 : 0.7 : 0 : -9  open: 0
# 0.6 : 0.75 : 0 : -12  open: 0
# 0.6 : 0.8 : 0 : -12  open: 1
# 0.6 : 0.85 : 0 : -12  open: 1
# 0.6 : 0.9 : 0 : -13  open: 1
# 0.65 : 0.7 : 0 : -10  open: 0
# 0.65 : 0.75 : 0 : -12  open: 0
# 0.65 : 0.8 : 0 : -13  open: 1
# 0.65 : 0.85 : 0 : -13  open: 1
# 0.65 : 0.9 : 0 : -16  open: 1
# 0.7 : 0.7 : 0 : -10  open: 0
# 0.7 : 0.75 : 0 : -14  open: 0
# 0.7 : 0.8 : 0 : -14  open: 1
# 0.7 : 0.85 : 0 : -17  open: 1
# 0.7 : 0.9 : 0 : -17  open: 1
# 0.75 : 0.7 : 0 : -10  open: 0
# 0.75 : 0.75 : 0 : -14  open: 0
# 0.75 : 0.8 : 0 : -14  open: 1
# 0.75 : 0.85 : 0 : -17  open: 1
# 0.75 : 0.9 : 0 : -17  open: 1
# 0.8 : 0.7 : 0 : -11  open: 0
# 0.8 : 0.75 : 0 : -14  open: 0
# 0.8 : 0.8 : 0 : -14  open: 1
# 0.8 : 0.85 : 0 : -17  open: 1
# 0.8 : 0.9 : 0 : -17  open: 1
# 0.85 : 0.7 : 0 : -15  open: 0
# 0.85 : 0.75 : 0 : -15  open: 0
# 0.85 : 0.8 : 0 : -16  open: 1
# 0.85 : 0.85 : 0 : -17  open: 1
# 0.85 : 0.9 : 0 : -17  open: 1
# 0.9 : 0.7 : 0 : -16  open: 0
# 0.9 : 0.75 : 0 : -18  open: 0
# 0.9 : 0.8 : 0 : -18  open: 1
# 0.9 : 0.85 : 0 : -18  open: 1
# 0.9 : 0.9 : 0 : -18  open: 1
# 0:00:19.996192

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open    high  \
# 172  172  2004      3   31 2004-03-31 22:00:00        2  0.75258  0.7669
# 173  173  2004      4    1 2004-04-01 22:00:00        3  0.76611  0.7691
#
#          low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 172  0.75251  0.76628  ...  0.746212    0.760010       172.0         172.0
# 173  0.75934  0.76635  ...  0.759756    0.773523       173.0          -1.0
#
#      closeprice  tpcloseprice  slindex  slprice  profit  profit1
# 172    0.760010        0.7669     -1.0 -1.00000  74.298        1
# 173    0.759756       -1.0000    173.0  0.75934 -63.540       -1
#
# [2 rows x 127 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [15]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    runstats35(alltrades,'130',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'140',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'160',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'170',atrperiod,sl,tp,tsl)
    
    
#     stats1 = runstats28(alltrades,'30',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'40',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'50',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'60',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'80',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'100',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'120',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'140',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'160',atrperiod,sl,tp,tsl)
# Out:
# ma_35_2003_2021_1_atr15atr_prev_ma35SMAvs3_prevx1
# allexecs:  59535
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5860/1423186368.py in <module>
#       4 for i in [15]:
#       5     atrperiod = 'atr'+str(i)+'atr_prev'
# ----> 6     runstats35(alltrades,'35',atrperiod,sl,tp,tsl)
#       7     runstats35(alltrades,'40',atrperiod,sl,tp,tsl)
#       8     runstats35(alltrades,'45',atrperiod,sl,tp,tsl)
#
# ~\notebooks\wm\tradestats.py in runstats35(alltrades, ma1, atrperiod, sl, tp, tsl)
#    3084 def runstats35(alltrades,ma1,atrperiod,sl,tp,tsl):
#    3085     ma2 = '3'
# -> 3086     runstats_ma_v35(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#    3087     ma2 = '5'
#    3088     runstats_ma_v35(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v35(alltrades, a, b, sv, aa, bb, atr, sl, tp, tsl, ff)
#    3108     conf['filename'] =    'ma_35_2003_2021_1_'+atr+'_'+sv+ff
#    3109     print(conf['filename'])
# -> 3110     stathyperparams2(alltrades,params,conf)
#    3111     return
#    3112
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1253     seq['lastrun'] = datetime.now()
#    1254     stats = stats.values.tolist()
# -> 1255     stats = execstats2_r(trades,stats,params,seq)
#    1256     stats = pd.DataFrame(stats)
#    1257
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1325             for ifrom in params[key][1]:
#    1326                 seq[key] = [imode,ifrom]
# -> 1327                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1328         elif (imode == 3):
#    1329             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1325             for ifrom in params[key][1]:
#    1326                 seq[key] = [imode,ifrom]
# -> 1327                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1328         elif (imode == 3):
#    1329             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1325             for ifrom in params[key][1]:
#    1326                 seq[key] = [imode,ifrom]
# -> 1327                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1328         elif (imode == 3):
#    1329             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1325             for ifrom in params[key][1]:
#    1326                 seq[key] = [imode,ifrom]
# -> 1327                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1328         elif (imode == 3):
#    1329             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1332                 if (ito>ifrom):
#    1333                     seq[key] = [imode,ifrom,ito]
# -> 1334                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1335
#    1336     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1312                     if (ito>ifrom):
#    1313                         seq[key] = [imode,ifrom,ito]
# -> 1314                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1315         elif (imode == 1):
#    1316             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1312                     if (ito>ifrom):
#    1313                         seq[key] = [imode,ifrom,ito]
# -> 1314                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1315         elif (imode == 1):
#    1316             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1312                     if (ito>ifrom):
#    1313                         seq[key] = [imode,ifrom,ito]
# -> 1314                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1315         elif (imode == 1):
#    1316             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1312                     if (ito>ifrom):
#    1313                         seq[key] = [imode,ifrom,ito]
# -> 1314                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1315         elif (imode == 1):
#    1316             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1312                     if (ito>ifrom):
#    1313                         seq[key] = [imode,ifrom,ito]
# -> 1314                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1315         elif (imode == 1):
#    1316             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1335
#    1336     else:
# -> 1337         stats = execstats2(trades,stats,params,seq)
#    1338     return stats
#    1339
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1344     else:
#    1345         seq['execs'] = seq['execs'] + 1
# -> 1346         df = calculatestats2(trades,params,seq)
#    1347         if (not df is None):
#    1348             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1385         imode = seq[kk][0]
#    1386         if ((imode == 0) or (imode == 3)):
# -> 1387             cond = (stats0[kk].values>=seq[kk][1])&(stats0[kk].values<seq[kk][2])
#    1388             timedump('1a')
#    1389         elif (imode == 1):
#
# KeyboardInterrupt:
