# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [3,5,7,35,40,45,60,80,100,120,140,160,200]
atrKey = [20]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma2(prices, maKey)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.530568

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma160SMAvs10_prev  ma160SMAvs20_prev  \
# 4748  0.73781  0.74102  ...          -0.018927          -0.023451
# 4749  0.74074  0.74715  ...          -0.017537          -0.022502
# 4750  0.74647  0.75144  ...          -0.015567          -0.021139
# 4751  0.74581  0.74655  ...          -0.012988          -0.019650
# 4752  0.74533  0.74631  ...          -0.011227          -0.018580
#
#       ma160SMAdiffseq_prev  ma200SMA_prev  ma200SMAdiffdiff_prev  \
# 4748                    -5       0.756790               0.000005
# 4749                    -5       0.756647               0.000028
# 4750                    -5       0.756498              -0.000007
# 4751                    -5       0.756389               0.000041
# 4752                    -5       0.756234              -0.000047
#
#       ma200SMAvs5_prev  ma200SMAvs10_prev  ma200SMAvs20_prev  \
# 4748         -0.018770          -0.023174          -0.027698
# 4749         -0.017297          -0.021789          -0.026754
# 4750         -0.014682          -0.019822          -0.025394
# 4751         -0.011827          -0.017271          -0.023933
# 4752         -0.010654          -0.015556          -0.022908
#
#       ma200SMAdiffseq_prev  atr20atr_prev
# 4748                    -5       0.006553
# 4749                    -5       0.006606
# 4750                    -5       0.006687
# 4751                    -5       0.006611
# 4752                    -5       0.006588
#
# [5 rows x 90 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr20atr_prev'
sl = [0.5,0.6,0.65,0.7,0.75,0.8,0.85,0.9]
tp = [0.7,0.75,0.8,0.85,0.9,1]
tsl = [0,0.3,0.5]
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp+[100],tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.5 : 0.7 : 0 : -12  open: 0
# 0.5 : 0.7 : 0.3 : -15  open: 1
# 0.5 : 0.7 : 0.5 : -16  open: 1
# 0.5 : 0.75 : 0 : -13  open: 1
# 0.5 : 0.75 : 0.3 : -15  open: 1
# 0.5 : 0.75 : 0.5 : -16  open: 1
# 0.5 : 0.8 : 0 : -13  open: 1
# 0.5 : 0.8 : 0.3 : -15  open: 2
# 0.5 : 0.8 : 0.5 : -16  open: 2
# 0.5 : 0.85 : 0 : -13  open: 1
# 0.5 : 0.85 : 0.3 : -15  open: 2
# 0.5 : 0.85 : 0.5 : -16  open: 2
# 0.5 : 0.9 : 0 : -13  open: 1
# 0.5 : 0.9 : 0.3 : -15  open: 2
# 0.5 : 0.9 : 0.5 : -16  open: 2
# 0.5 : 1 : 0 : -14  open: 1
# 0.5 : 1 : 0.3 : -15  open: 2
# 0.5 : 1 : 0.5 : -18  open: 2
# 0.5 : 100 : 0 : -15  open: 1
# 0.6 : 0.7 : 0 : -12  open: 0
# 0.6 : 0.7 : 0.3 : -15  open: 1
# 0.6 : 0.7 : 0.5 : -16  open: 1
# 0.6 : 0.75 : 0 : -13  open: 1
# 0.6 : 0.75 : 0.3 : -15  open: 1
# 0.6 : 0.75 : 0.5 : -16  open: 1
# 0.6 : 0.8 : 0 : -13  open: 1
# 0.6 : 0.8 : 0.3 : -15  open: 2
# 0.6 : 0.8 : 0.5 : -16  open: 2
# 0.6 : 0.85 : 0 : -13  open: 1
# 0.6 : 0.85 : 0.3 : -15  open: 2
# 0.6 : 0.85 : 0.5 : -16  open: 2
# 0.6 : 0.9 : 0 : -13  open: 1
# 0.6 : 0.9 : 0.3 : -15  open: 2
# 0.6 : 0.9 : 0.5 : -16  open: 2
# 0.6 : 1 : 0 : -14  open: 1
# 0.6 : 1 : 0.3 : -15  open: 2
# 0.6 : 1 : 0.5 : -18  open: 2
# 0.6 : 100 : 0 : -22  open: 1
# 0.65 : 0.7 : 0 : -12  open: 0
# 0.65 : 0.7 : 0.3 : -15  open: 1
# 0.65 : 0.7 : 0.5 : -16  open: 1
# 0.65 : 0.75 : 0 : -13  open: 1
# 0.65 : 0.75 : 0.3 : -15  open: 1
# 0.65 : 0.75 : 0.5 : -16  open: 1
# 0.65 : 0.8 : 0 : -13  open: 1
# 0.65 : 0.8 : 0.3 : -15  open: 2
# 0.65 : 0.8 : 0.5 : -16  open: 2
# 0.65 : 0.85 : 0 : -13  open: 1
# 0.65 : 0.85 : 0.3 : -15  open: 2
# 0.65 : 0.85 : 0.5 : -17  open: 2
# 0.65 : 0.9 : 0 : -13  open: 1
# 0.65 : 0.9 : 0.3 : -15  open: 2
# 0.65 : 0.9 : 0.5 : -17  open: 2
# 0.65 : 1 : 0 : -16  open: 1
# 0.65 : 1 : 0.3 : -16  open: 2
# 0.65 : 1 : 0.5 : -18  open: 2
# 0.65 : 100 : 0 : -22  open: 1
# 0.7 : 0.7 : 0 : -12  open: 0
# 0.7 : 0.7 : 0.3 : -15  open: 1
# 0.7 : 0.7 : 0.5 : -16  open: 1
# 0.85 : 0.85 : 0 : -17  open: 1
# 0.85 : 0.85 : 0.3 : -18  open: 2
# 0.85 : 0.85 : 0.5 : -24  open: 2
# 0.85 : 0.9 : 0 : -17  open: 1
# 0.85 : 0.9 : 0.3 : -18  open: 2
# 0.85 : 0.9 : 0.5 : -24  open: 2
# 0.85 : 1 : 0 : -17  open: 1
# 0.85 : 1 : 0.3 : -18  open: 2
# 0.85 : 1 : 0.5 : -24  open: 2
# 0.85 : 100 : 0 : -28  open: 1
# 0.9 : 0.7 : 0 : -16  open: 0
# 0.9 : 0.7 : 0.3 : -17  open: 1
# 0.9 : 0.7 : 0.5 : -23  open: 1
# 0.9 : 0.75 : 0 : -16  open: 1
# 0.9 : 0.75 : 0.3 : -17  open: 1
# 0.9 : 0.75 : 0.5 : -23  open: 1
# 0.9 : 0.8 : 0 : -16  open: 1
# 0.9 : 0.8 : 0.3 : -17  open: 2
# 0.9 : 0.8 : 0.5 : -23  open: 2
# 0.9 : 0.85 : 0 : -17  open: 1
# 0.9 : 0.85 : 0.3 : -18  open: 2
# 0.9 : 0.85 : 0.5 : -24  open: 2
# 0.9 : 0.9 : 0 : -17  open: 1
# 0.9 : 0.9 : 0.3 : -18  open: 2
# 0.9 : 0.9 : 0.5 : -24  open: 2
# 0.9 : 1 : 0 : -20  open: 1
# 0.9 : 1 : 0.3 : -22  open: 2
# 0.9 : 1 : 0.5 : -24  open: 2
# 0.9 : 100 : 0 : -31  open: 1
# 0:02:01.441635

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open     high  \
# 202  202  2004      5   12 2004-05-12 21:00:00        2  0.69659  0.70232
# 203  203  2004      5   13 2004-05-13 21:00:00        3  0.69832  0.70005
#
#          low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 202  0.69390  0.69845  ...  0.690775    0.704731       203.0          -1.0
# 203  0.68462  0.68816  ...  0.692927    0.705871       203.0          -1.0
#
#      closeprice  tpcloseprice  slindex  slprice   profit  profit1
# 202    0.690775          -1.0    203.0  0.68462 -58.1475       -1
# 203    0.692927          -1.0    203.0  0.68462 -53.9350       -1
#
# [2 rows x 109 columns]

# %%
# from joblib import Parallel, delayed
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    runstats40(alltrades,'80',atrperiod,sl,tp,tsl,5)
    runstats40(alltrades,'100',atrperiod,sl,tp,tsl,5)
    
# maKey  = [3,5,7,35,40,45,60,80,100,120,140,160,200]
# Out:
# ma_40_2003_2021_1_atr20atr_prev_ma35SMAvs5_prevx1
# allexecs:  244944
# ____progress:   0.13 %
# elapsed:        0:00:30.074871
# last run:       0:00:30.074871
# remaining:      6:12:40.986534
# estimated end:  2021-12-20 02:53:31.439956
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2064/2457068989.py in <module>
#       5 for i in [20]:
#       6     atrperiod = 'atr'+str(i)+'atr_prev'
# ----> 7     runstats40(alltrades,'35',atrperiod,sl,tp,tsl)
#       8     runstats40(alltrades,'40',atrperiod,sl,tp,tsl)
#       9
#
# ~\notebooks\wm\tradestats.py in runstats40(alltrades, ma1, atrperiod, sl, tp, tsl, ma2)
#    3133 def runstats40(alltrades,ma1,atrperiod,sl,tp,tsl,ma2=5):
#    3134     ma2 = str(ma2)
# -> 3135     runstats_ma_v40(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#    3136     runstats_ma_v40(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,[100],[0],'x2')
#    3137
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v40(alltrades, a, b, sv, aa, bb, atr, sl, tp, tsl, ff)
#    3154     conf['filename'] =    'ma_40_2003_2021_1_'+atr+'_'+sv+ff
#    3155     print(conf['filename'])
# -> 3156     stathyperparams2(alltrades,params,conf)
#    3157     return
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1253     seq['lastrun'] = datetime.now()
#    1254     stats = stats.values.tolist()
# -> 1255     stats = execstats2_r(trades,stats,params,seq)
#    1256     stats = pd.DataFrame(stats)
#    1257
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1327             for ifrom in params[key][1]:
#    1328                 seq[key] = [imode,ifrom]
# -> 1329                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1330         elif (imode == 3):
#    1331             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1334                 if (ito>ifrom):
#    1335                     seq[key] = [imode,ifrom,ito]
# -> 1336                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1337
#    1338     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1314                     if (ito>ifrom):
#    1315                         seq[key] = [imode,ifrom,ito]
# -> 1316                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1317         elif (imode == 1):
#    1318             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1337
#    1338     else:
# -> 1339         stats = execstats2(trades,stats,params,seq)
#    1340     return stats
#    1341
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1346     else:
#    1347         seq['execs'] = seq['execs'] + 1
# -> 1348         df = calculatestats2(trades,params,seq)
#    1349         if (not df is None):
#    1350             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1387         imode = seq[kk][0]
#    1388         if ((imode == 0) or (imode == 3)):
# -> 1389             cond = (stats0[kk].values>=seq[kk][1])&(stats0[kk].values<seq[kk][2])
#    1390             timedump('1a')
#    1391         elif (imode == 1):
#
# KeyboardInterrupt:
