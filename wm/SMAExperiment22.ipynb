# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [5,30,40,50,60,80,100,120,130,140,160]
atrKey = [20]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma(prices, maKey)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.116325

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma140SMAdiff_prev  ma140SMAdiff2_prev  \
# 4748  0.73781  0.74102  ...          -0.000129           -0.000273
# 4749  0.74074  0.74715  ...          -0.000171           -0.000299
# 4750  0.74647  0.75144  ...          -0.000136           -0.000307
# 4751  0.74581  0.74655  ...          -0.000070           -0.000206
# 4752  0.74533  0.74631  ...          -0.000133           -0.000203
#
#       ma140SMAdiffdiff_prev  ma140SMAclose_prev  ma160SMA_prev  \
# 4748               0.000015           -0.008580       0.752543
# 4749              -0.000042           -0.009130       0.752395
# 4750               0.000035           -0.002864       0.752243
# 4751               0.000066            0.001496       0.752106
# 4752              -0.000063           -0.003261       0.751905
#
#       ma160SMAdiff_prev  ma160SMAdiff2_prev  ma160SMAdiffdiff_prev  \
# 4748          -0.000165           -0.000357               0.000026
# 4749          -0.000148           -0.000313               0.000017
# 4750          -0.000152           -0.000300              -0.000004
# 4751          -0.000137           -0.000289               0.000015
# 4752          -0.000201           -0.000338              -0.000064
#
#       ma160SMAclose_prev  atr20atr_prev
# 4748           -0.010803       0.006553
# 4749           -0.011375       0.006606
# 4750           -0.005093       0.006687
# 4751           -0.000666       0.006611
# 4752           -0.005355       0.006588
#
# [5 rows x 67 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr20atr_prev'
sl = [0.3,0.4,0.5,0.6,0.7,0.8,0.9,1,1.2,1.4,1.6,1.8,2,2.4,2.8,3.2]
tp = [100]
tsl = []
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.3 : 100 : -10  open: 1
# 0.4 : 100 : -12  open: 1
# 0.5 : 100 : -15  open: 1
# 0.6 : 100 : -22  open: 1
# 0.7 : 100 : -28  open: 1
# 0.8 : 100 : -28  open: 1
# 0.9 : 100 : -31  open: 1
# 1 : 100 : -56  open: 16
# 1.2 : 100 : -60  open: 18
# 1.4 : 100 : -131  open: 18
# 1.6 : 100 : -134  open: 18
# 1.8 : 100 : -134  open: 18
# 2 : 100 : -257  open: 22
# 2.4 : 100 : -321  open: 26
# 2.8 : 100 : -408  open: 28
# 3.2 : 100 : -757  open: 32
# 0:01:02.601824

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open     high  \
# 162  162  2004      3   17 2004-03-17 22:00:00        2  0.74192  0.74355
# 163  163  2004      3   18 2004-03-18 22:00:00        3  0.74107  0.75308
#
#         low    close  ...  tpcloseprice  slindex  slprice   profit  \
# 162  0.7359  0.74081  ...            -1    162.0  0.73590 -37.5945
# 163  0.7392  0.75065  ...            -1    164.0  0.74393  59.0635
#
#      nextbar_id  nextbar_open  nextbar_close  nextbar_low  nextbar_high  \
# 162       171.0       0.74646        0.75252      0.74570       0.75555
# 163       172.0       0.75258        0.76628      0.75251       0.76690
#
#      profit1
# 162       -1
# 163        1
#
# [2 rows x 91 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    # stats1 = runstats_ma_v4(alltrades,'ma5SMAdiff_prev','ma5SMAdiffdiff_prev','ma5SMAdiff2_prev','ma5SMAclose_prev')
    stats1 = runstats_ma_v22(alltrades,'ma30SMAdiff_prev','ma30SMAdiffdiff_prev','ma30SMAdiff2_prev','ma30SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma40SMAdiff_prev','ma40SMAdiffdiff_prev','ma40SMAdiff2_prev','ma40SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma50SMAdiff_prev','ma50SMAdiffdiff_prev','ma50SMAdiff2_prev','ma50SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma60SMAdiff_prev','ma60SMAdiffdiff_prev','ma60SMAdiff2_prev','ma60SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma80SMAdiff_prev','ma80SMAdiffdiff_prev','ma80SMAdiff2_prev','ma80SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma100SMAdiff_prev','ma100SMAdiffdiff_prev','ma100SMAdiff2_prev','ma100SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma120SMAdiff_prev','ma120SMAdiffdiff_prev','ma120SMAdiff2_prev','ma120SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma130SMAdiff_prev','ma130SMAdiffdiff_prev','ma130SMAdiff2_prev','ma130SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma140SMAdiff_prev','ma140SMAdiffdiff_prev','ma140SMAdiff2_prev','ma140SMAclose_prev',atrperiod,sl,tp)
    stats1 = runstats_ma_v22(alltrades,'ma160SMAdiff_prev','ma160SMAdiffdiff_prev','ma160SMAdiff2_prev','ma160SMAclose_prev',atrperiod,sl,tp)
# Out:
# ma_frac_2003_2021_1_atr20atr_prev_ma30SMAdiff_prev
# allexecs:  3888
# ____progress:   24.6142
# elapsed:        0:00:30.015425
# last run:       0:00:30.015425
# remaining:      0:01:31.928120
# estimated end:  2021-12-04 21:44:35.928118
# ____progress:   49.5113
# elapsed:        0:01:00.034176
# last run:       0:00:30.018751
# remaining:      0:01:01.219266
# estimated end:  2021-12-04 21:44:35.238015
# ____progress:   76.2603
# elapsed:        0:01:30.035326
# last run:       0:00:30.001150
# remaining:      0:00:28.027860
# estimated end:  2021-12-04 21:44:32.047759
# finish:         2021-12-04 21:44:31.831977
# duration:       0:01:57.932586
# ma_frac_2003_2021_1_atr20atr_prev_ma40SMAdiff_prev
# allexecs:  3888
# ____progress:   25.1543
# elapsed:        0:00:30.021220
# last run:       0:00:30.021220
# remaining:      0:01:29.326943
# estimated end:  2021-12-04 21:46:31.260141
# ____progress:   50.1800
# elapsed:        0:01:00.047268
# last run:       0:00:30.026048
# remaining:      0:00:59.616380
# estimated end:  2021-12-04 21:46:31.575626
# ____progress:   76.4146
# elapsed:        0:01:30.061894
# last run:       0:00:30.015626
# remaining:      0:00:27.797629
# estimated end:  2021-12-04 21:46:29.772501
# finish:         2021-12-04 21:46:28.071244
# duration:       0:01:56.236266
# ma_frac_2003_2021_1_atr20atr_prev_ma50SMAdiff_prev
# allexecs:  3888
# ____progress:   22.9938
# elapsed:        0:00:30.001637
# last run:       0:00:30.001637
# remaining:      0:01:40.475281
# estimated end:  2021-12-04 21:48:38.626167
# ____progress:   47.1965
# elapsed:        0:01:00.040656
# last run:       0:00:30.039019
# remaining:      0:01:07.173551
# estimated end:  2021-12-04 21:48:35.362451
# ____progress:   73.3796
# elapsed:        0:01:30.044214
# last run:       0:00:30.003558
# remaining:      0:00:32.665882
# estimated end:  2021-12-04 21:48:30.858340
# finish:         2021-12-04 21:48:29.813391
# duration:       0:02:01.739141
# ma_frac_2003_2021_1_atr20atr_prev_ma60SMAdiff_prev
# allexecs:  3888
# ____progress:   24.0741
# elapsed:        0:00:30.022606
# last run:       0:00:30.022606
# remaining:      0:01:34.686680
# estimated end:  2021-12-04 21:50:34.604681
# ____progress:   48.5597
# elapsed:        0:01:00.061706
# last run:       0:00:30.040102
# remaining:      0:01:03.624689
# estimated end:  2021-12-04 21:50:33.582792
# ____progress:   74.0226
# elapsed:        0:01:30.083416
# last run:       0:00:30.020708
# remaining:      0:00:31.613707
# estimated end:  2021-12-04 21:50:31.592518
# finish:         2021-12-04 21:50:31.508200
# duration:       0:02:01.690809
# ma_frac_2003_2021_1_atr20atr_prev_ma80SMAdiff_prev
# allexecs:  3888
# ____progress:   24.7171
# elapsed:        0:00:30.030677
# last run:       0:00:30.030677
# remaining:      0:01:31.467005
# estimated end:  2021-12-04 21:52:33.091993
# ____progress:   50.2572
# elapsed:        0:01:00.033210
# last run:       0:00:30.002533
# remaining:      0:00:59.418745
# estimated end:  2021-12-04 21:52:31.047266
# ____progress:   75.8230
# elapsed:        0:01:30.049824
# last run:       0:00:30.016614
# remaining:      0:00:28.713309
# estimated end:  2021-12-04 21:52:30.357444
# finish:         2021-12-04 21:52:31.881941
# duration:       0:02:00.370741
# ma_frac_2003_2021_1_atr20atr_prev_ma100SMAdiff_prev
# allexecs:  3888
# ____progress:   21.7850
# elapsed:        0:00:30.030453
# last run:       0:00:30.030453
# remaining:      0:01:47.818899
# estimated end:  2021-12-04 21:54:49.809464
# ____progress:   43.0556
# elapsed:        0:01:00.052365
# last run:       0:00:30.021912
# remaining:      0:01:19.424096
# estimated end:  2021-12-04 21:54:51.436573
# ____progress:   67.8755
# elapsed:        0:01:30.054124
# last run:       0:00:30.001759
# remaining:      0:00:42.621296
# estimated end:  2021-12-04 21:54:44.635532
# ____progress:   93.3385
# elapsed:        0:02:00.060145
# last run:       0:00:30.006021
# remaining:      0:00:08.568635
# estimated end:  2021-12-04 21:54:40.588892
# finish:         2021-12-04 21:54:41.629196
# duration:       0:02:09.744255
# ma_frac_2003_2021_1_atr20atr_prev_ma120SMAdiff_prev
# allexecs:  3888
# ____progress:   22.4280
# elapsed:        0:00:30.011591
# last run:       0:00:30.011591
# remaining:      0:01:43.801558
# estimated end:  2021-12-04 21:56:55.520346
# ____progress:   44.3673
# elapsed:        0:01:00.031892
# last run:       0:00:30.020301
# remaining:      0:01:15.274772
# estimated end:  2021-12-04 21:56:57.013861
# ____progress:   69.0072
# elapsed:        0:01:30.048071
# last run:       0:00:30.016179
# remaining:      0:00:40.442760
# estimated end:  2021-12-04 21:56:52.198028
# ____progress:   90.7922
# elapsed:        0:02:00.098670
# last run:       0:00:30.050599
# remaining:      0:00:12.179978
# estimated end:  2021-12-04 21:56:53.985845
# finish:         2021-12-04 21:56:57.453456
# duration:       0:02:15.821259
# ma_frac_2003_2021_1_atr20atr_prev_ma130SMAdiff_prev
# allexecs:  3888
# ____progress:   20.6019
# elapsed:        0:00:30.038675
# last run:       0:00:30.038675
# remaining:      0:01:55.767028
# estimated end:  2021-12-04 21:59:23.348157
# ____progress:   41.9496
# elapsed:        0:01:00.070488
# last run:       0:00:30.030814
# remaining:      0:01:23.126359
# estimated end:  2021-12-04 21:59:20.738302
# ____progress:   68.9043
# elapsed:        0:01:30.081777
# last run:       0:00:30.011289
# remaining:      0:00:40.652806
# estimated end:  2021-12-04 21:59:08.276038
# ____progress:   93.8529
# elapsed:        0:02:00.104725
# last run:       0:00:30.022948
# remaining:      0:00:07.866547
# estimated end:  2021-12-04 21:59:05.513727
# finish:         2021-12-04 21:59:06.482129
# duration:       0:02:09.025673
# ma_frac_2003_2021_1_atr20atr_prev_ma140SMAdiff_prev
# allexecs:  3888
# ____progress:   22.6337
# elapsed:        0:00:30.019333
# last run:       0:00:30.019333
# remaining:      0:01:42.611538
# estimated end:  2021-12-04 22:01:19.193122
# ____progress:   45.4475
# elapsed:        0:01:00.037223
# last run:       0:00:30.017890
# remaining:      0:01:12.065054
# estimated end:  2021-12-04 22:01:18.664528
# ____progress:   69.9331
# elapsed:        0:01:30.046289
# last run:       0:00:30.009066
# remaining:      0:00:38.714274
# estimated end:  2021-12-04 22:01:15.322814
# ____progress:   94.8560
# elapsed:        0:02:00.077702
# last run:       0:00:30.031413
# remaining:      0:00:06.511806
# estimated end:  2021-12-04 22:01:13.151759
# finish:         2021-12-04 22:01:14.207197
# duration:       0:02:07.723068
# ma_frac_2003_2021_1_atr20atr_prev_ma160SMAdiff_prev
# allexecs:  3888
# ____progress:   21.8107
# elapsed:        0:00:30.044043
# last run:       0:00:30.044043
# remaining:      0:01:47.705060
# estimated end:  2021-12-04 22:03:32.037297
# ____progress:   40.6121
# elapsed:        0:01:00.067243
# last run:       0:00:30.023200
# remaining:      0:01:27.837406
# estimated end:  2021-12-04 22:03:42.192843
# ____progress:   65.0463
# elapsed:        0:01:30.113268
# last run:       0:00:30.046025
# remaining:      0:00:48.423856
# estimated end:  2021-12-04 22:03:32.825318
# ____progress:   84.6965
# elapsed:        0:02:00.129374
# last run:       0:00:30.016106
# remaining:      0:00:21.705733
# estimated end:  2021-12-04 22:03:36.124301
# finish:         2021-12-04 22:03:44.041463
# duration:       0:02:29.831266
