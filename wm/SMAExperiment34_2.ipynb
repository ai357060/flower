# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [3,5,7,150,170]
atrKey = [20]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma2(prices, maKey,3,5,7)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.208236

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma150SMAvs5_prev  ma150SMAvs7_prev  \
# 4748  0.73781  0.74102  ...         -0.013075         -0.015156
# 4749  0.74074  0.74715  ...         -0.011522         -0.013495
# 4750  0.74647  0.75144  ...         -0.008956         -0.011019
# 4751  0.74581  0.74655  ...         -0.006167         -0.008537
# 4752  0.74533  0.74631  ...         -0.005073         -0.006786
#
#       ma150SMAdiffseq_prev  ma170SMA_prev  ma170SMAdiffdiff_prev  \
# 4748                    -5       0.754232              -0.000058
# 4749                    -5       0.753936              -0.000032
# 4750                    -5       0.753678               0.000038
# 4751                    -5       0.753412              -0.000008
# 4752                    -5       0.753174               0.000027
#
#       ma170SMAvs3_prev  ma170SMAvs5_prev  ma170SMAvs7_prev  \
# 4748         -0.013928         -0.016212         -0.018293
# 4749         -0.012529         -0.014586         -0.016559
# 4750         -0.010375         -0.011862         -0.013925
# 4751         -0.006876         -0.008850         -0.011221
# 4752         -0.004794         -0.007594         -0.009307
#
#       ma170SMAdiffseq_prev  atr20atr_prev
# 4748                    -5       0.006553
# 4749                    -5       0.006606
# 4750                    -5       0.006687
# 4751                    -5       0.006611
# 4752                    -5       0.006588
#
# [5 rows x 42 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr20atr_prev'
sl = [0.6,0.65,0.7,0.75,0.8,0.85,0.9]
tp = [0.7,0.75,0.8,0.85,0.9]
tsl = [0]
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp+[100],tsl,2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.6 : 0.7 : 0 : -12  open: 0
# 0.6 : 0.75 : 0 : -13  open: 1
# 0.6 : 0.8 : 0 : -13  open: 1
# 0.6 : 0.85 : 0 : -13  open: 1
# 0.6 : 0.9 : 0 : -13  open: 1
# 0.65 : 0.7 : 0 : -12  open: 0
# 0.65 : 0.75 : 0 : -13  open: 1
# 0.65 : 0.8 : 0 : -13  open: 1
# 0.65 : 0.85 : 0 : -13  open: 1
# 0.65 : 0.9 : 0 : -13  open: 1
# 0.7 : 0.7 : 0 : -12  open: 0
# 0.7 : 0.75 : 0 : -13  open: 1
# 0.7 : 0.8 : 0 : -13  open: 1
# 0.7 : 0.85 : 0 : -17  open: 1
# 0.7 : 0.9 : 0 : -17  open: 1
# 0.75 : 0.7 : 0 : -12  open: 0
# 0.75 : 0.75 : 0 : -13  open: 1
# 0.75 : 0.8 : 0 : -13  open: 1
# 0.75 : 0.85 : 0 : -17  open: 1
# 0.75 : 0.9 : 0 : -17  open: 1
# 0.8 : 0.7 : 0 : -12  open: 0
# 0.8 : 0.75 : 0 : -13  open: 1
# 0.8 : 0.8 : 0 : -13  open: 1
# 0.8 : 0.85 : 0 : -17  open: 1
# 0.8 : 0.9 : 0 : -17  open: 1
# 0.85 : 0.7 : 0 : -13  open: 0
# 0.85 : 0.75 : 0 : -14  open: 1
# 0.85 : 0.8 : 0 : -14  open: 1
# 0.85 : 0.85 : 0 : -17  open: 1
# 0.85 : 0.9 : 0 : -17  open: 1
# 0.9 : 0.7 : 0 : -16  open: 0
# 0.9 : 0.75 : 0 : -16  open: 1
# 0.9 : 0.8 : 0 : -16  open: 1
# 0.9 : 0.85 : 0 : -17  open: 1
# 0.9 : 0.9 : 0 : -17  open: 1
# 0:00:17.066850

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open    high  \
# 172  172  2004      3   31 2004-03-31 22:00:00        2  0.75258  0.7669
# 173  173  2004      4    1 2004-04-01 22:00:00        3  0.76611  0.7691
#
#          low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 172  0.75251  0.76628  ...  0.745888    0.760388       172.0         172.0
# 173  0.75934  0.76635  ...  0.759720    0.773565       173.0          -1.0
#
#      closeprice  tpcloseprice  slindex  slprice  profit  profit1
# 172    0.760388        0.7669     -1.0 -1.00000  78.078        1
# 173    0.759720       -1.0000    173.0  0.75934 -63.897       -1
#
# [2 rows x 61 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    runstats34(alltrades,'150',atrperiod,sl,tp,tsl)
    runstats34(alltrades,'170',atrperiod,sl,tp,tsl)


    
#     stats1 = runstats28(alltrades,'30',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'40',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'50',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'60',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'80',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'100',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'120',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'140',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'160',atrperiod,sl,tp,tsl)
# Out:
# ma_34_2003_2021_1_atr20atr_prev_ma150SMAvs3_prevx1
# allexecs:  59535
# ____progress:   1.7872
# elapsed:        0:00:30.023078
# last run:       0:00:30.023078
# remaining:      0:27:29.886648
# estimated end:  2021-12-19 11:45:05.266944
# ____progress:   3.7709
# elapsed:        0:01:00.037022
# last run:       0:00:30.013944
# remaining:      0:25:32.080619
# estimated end:  2021-12-19 11:43:37.474859
# ____progress:   5.7999
# elapsed:        0:01:30.041073
# last run:       0:00:30.004051
# remaining:      0:24:22.404708
# estimated end:  2021-12-19 11:42:57.803996
# ____progress:   7.8273
# elapsed:        0:02:00.060028
# last run:       0:00:30.017958
# remaining:      0:23:33.797004
# estimated end:  2021-12-19 11:42:39.215249
# ____progress:   9.8262
# elapsed:        0:02:30.070942
# last run:       0:00:30.010911
# remaining:      0:22:57.189491
# estimated end:  2021-12-19 11:42:32.618647
# ____progress:   11.8468
# elapsed:        0:03:00.098031
# last run:       0:00:30.026093
# remaining:      0:22:20.125459
# estimated end:  2021-12-19 11:42:25.580708
# ____progress:   13.8574
# elapsed:        0:03:30.120032
# last run:       0:00:30.022001
# remaining:      0:21:46.182526
# estimated end:  2021-12-19 11:42:21.660774
# ____progress:   15.9133
# elapsed:        0:04:00.156805
# last run:       0:00:30.036773
# remaining:      0:21:08.998292
# estimated end:  2021-12-19 11:42:14.512315
# ____progress:   17.9424
# estimated end:  2021-12-19 11:55:57.032373
# ____progress:   62.9176
# elapsed:        0:24:31.322031
# last run:       0:00:30.018976
# remaining:      0:14:27.167934
# estimated end:  2021-12-19 11:56:03.847183
# ____progress:   64.0296
# elapsed:        0:25:01.324891
# last run:       0:00:30.002860
# remaining:      0:14:03.412186
# estimated end:  2021-12-19 11:56:10.095296
# ____progress:   65.1365
# elapsed:        0:25:31.365877
# last run:       0:00:30.040986
# remaining:      0:13:39.645430
# estimated end:  2021-12-19 11:56:16.368525
# ____progress:   66.2367
# elapsed:        0:26:01.369071
# last run:       0:00:30.003194
# remaining:      0:13:15.888819
# estimated end:  2021-12-19 11:56:22.615108
# ____progress:   67.3520
# elapsed:        0:26:31.407088
# last run:       0:00:30.038017
# remaining:      0:12:51.414524
# estimated end:  2021-12-19 11:56:28.178830
# ____progress:   68.4673
# elapsed:        0:27:01.427796
# last run:       0:00:30.020708
# remaining:      0:12:26.750994
# estimated end:  2021-12-19 11:56:33.536008
# ____progress:   69.5742
# elapsed:        0:27:31.471211
# last run:       0:00:30.043415
# remaining:      0:12:02.212151
# estimated end:  2021-12-19 11:56:39.040580
# ____progress:   70.6895
# elapsed:        0:28:01.483251
# last run:       0:00:30.012040
# remaining:      0:11:37.205245
# estimated end:  2021-12-19 11:56:44.046720
# ____progress:   71.7746
# elapsed:        0:28:31.505758
# last run:       0:00:30.022507
# remaining:      0:11:13.051011
# estimated end:  2021-12-19 11:56:49.913987
# ____progress:   72.7270
# elapsed:        0:29:01.522362
# last run:       0:00:30.016604
# remaining:      0:10:53.080941
# estimated end:  2021-12-19 11:56:59.960521
# ____progress:   73.6777
# elapsed:        0:29:31.574359
# last run:       0:00:30.051997
# remaining:      0:10:32.918607
# estimated end:  2021-12-19 11:57:09.850184
# ____progress:   74.6603
# elapsed:        0:30:01.582780
# last run:       0:00:30.008421
# remaining:      0:10:11.457577
# estimated end:  2021-12-19 11:57:18.398574
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4884/3172381417.py in <module>
#       4 for i in [20]:
#       5     atrperiod = 'atr'+str(i)+'atr_prev'
# ----> 6     runstats34(alltrades,'150',atrperiod,sl,tp,tsl)
#       7     runstats34(alltrades,'170',atrperiod,sl,tp,tsl)
#       8
#
# ~\notebooks\wm\tradestats.py in runstats34(alltrades, ma1, atrperiod, sl, tp, tsl)
#    3027 def runstats34(alltrades,ma1,atrperiod,sl,tp,tsl):
#    3028     ma2 = '3'
# -> 3029     runstats_ma_v34(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#    3030     ma2 = '5'
#    3031     runstats_ma_v34(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v34(alltrades, a, b, sv, aa, bb, atr, sl, tp, tsl, ff)
#    3051     conf['filename'] =    'ma_34_2003_2021_1_'+atr+'_'+sv+ff
#    3052     print(conf['filename'])
# -> 3053     stathyperparams2(alltrades,params,conf)
#    3054     return
#    3055
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1226     seq['lastrun'] = datetime.now()
#    1227     stats = stats.values.tolist()
# -> 1228     stats = execstats2_r(trades,stats,params,seq)
#    1229     stats = pd.DataFrame(stats)
#    1230
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1304                 if (ito>ifrom):
#    1305                     seq[key] = [imode,ifrom,ito]
# -> 1306                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1307
#    1308     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1307
#    1308     else:
# -> 1309         stats = execstats2(trades,stats,params,seq)
#    1310     return stats
#    1311
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1316     else:
#    1317         seq['execs'] = seq['execs'] + 1
# -> 1318         df = calculatestats2(trades,params,seq)
#    1319         if (not df is None):
#    1320             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1341     timedump('1')
#    1342
# -> 1343     stats0 = trades.copy()
#    1344 #     for kk in params.keys():
#    1345 #         imode = seq[kk][0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5931         dtype: object
#    5932         """
# -> 5933         data = self._mgr.copy(deep=deep)
#    5934         self._clear_item_cache()
#    5935         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     597             new_axes = list(self.axes)
#     598
# --> 599         res = self.apply("copy", deep=deep)
#     600         res.axes = new_axes
#     601
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     648         values = self.values
#     649         if deep:
# --> 650             values = values.copy()
#     651         return self.make_block_same_class(values)
#     652
#
# KeyboardInterrupt:
