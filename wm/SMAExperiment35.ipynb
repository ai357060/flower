# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import modin.pandas as md
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [3,5,7,35,40,45,50,60,80,100,120,130,140,150,160,170]
atrKey = [10]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma2(prices, maKey,3,5,7)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.728567

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]
# Out:
# PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma160SMAvs5_prev  ma160SMAvs7_prev  \
# 4748  0.73781  0.74102  ...         -0.014523         -0.016605
# 4749  0.74074  0.74715  ...         -0.013045         -0.015018
# 4750  0.74647  0.75144  ...         -0.010427         -0.012490
# 4751  0.74581  0.74655  ...         -0.007544         -0.009915
# 4752  0.74533  0.74631  ...         -0.006325         -0.008038
#
#       ma160SMAdiffseq_prev  ma170SMA_prev  ma170SMAdiffdiff_prev  \
# 4748                    -5       0.754232              -0.000058
# 4749                    -5       0.753936              -0.000032
# 4750                    -5       0.753678               0.000038
# 4751                    -5       0.753412              -0.000008
# 4752                    -5       0.753174               0.000027
#
#       ma170SMAvs3_prev  ma170SMAvs5_prev  ma170SMAvs7_prev  \
# 4748         -0.013928         -0.016212         -0.018293
# 4749         -0.012529         -0.014586         -0.016559
# 4750         -0.010375         -0.011862         -0.013925
# 4751         -0.006876         -0.008850         -0.011221
# 4752         -0.004794         -0.007594         -0.009307
#
#       ma170SMAdiffseq_prev  atr10atr_prev
# 4748                    -5       0.005612
# 4749                    -5       0.005672
# 4750                    -5       0.005927
# 4751                    -5       0.005828
# 4752                    -5       0.006149
#
# [5 rows x 108 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr10atr_prev'
sl = [0.6,0.65,0.7,0.75,0.8,0.85,0.9]
tp = [0.7,0.75,0.8,0.85,0.9]
tsl = [0]
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp+[100],tsl,2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.6 : 0.7 : 0 : -10  open: 0
# 0.6 : 0.75 : 0 : -10  open: 0
# 0.6 : 0.8 : 0 : -10  open: 1
# 0.6 : 0.85 : 0 : -16  open: 1
# 0.6 : 0.9 : 0 : -16  open: 1
# 0.65 : 0.7 : 0 : -12  open: 0
# 0.65 : 0.75 : 0 : -14  open: 0
# 0.65 : 0.8 : 0 : -17  open: 1
# 0.65 : 0.85 : 0 : -17  open: 1
# 0.65 : 0.9 : 0 : -17  open: 1
# 0.7 : 0.7 : 0 : -13  open: 0
# 0.7 : 0.75 : 0 : -14  open: 0
# 0.7 : 0.8 : 0 : -17  open: 1
# 0.7 : 0.85 : 0 : -17  open: 1
# 0.7 : 0.9 : 0 : -17  open: 1
# 0.75 : 0.7 : 0 : -13  open: 0
# 0.75 : 0.75 : 0 : -14  open: 0
# 0.75 : 0.8 : 0 : -17  open: 1
# 0.75 : 0.85 : 0 : -17  open: 1
# 0.75 : 0.9 : 0 : -17  open: 1
# 0.8 : 0.7 : 0 : -13  open: 0
# 0.8 : 0.75 : 0 : -14  open: 0
# 0.8 : 0.8 : 0 : -17  open: 1
# 0.8 : 0.85 : 0 : -17  open: 1
# 0.8 : 0.9 : 0 : -17  open: 1
# 0.85 : 0.7 : 0 : -16  open: 0
# 0.85 : 0.75 : 0 : -16  open: 0
# 0.85 : 0.8 : 0 : -17  open: 1
# 0.85 : 0.85 : 0 : -17  open: 1
# 0.85 : 0.9 : 0 : -17  open: 1
# 0.9 : 0.7 : 0 : -22  open: 0
# 0.9 : 0.75 : 0 : -22  open: 0
# 0.9 : 0.8 : 0 : -22  open: 1
# 0.9 : 0.85 : 0 : -22  open: 1
# 0.9 : 0.9 : 0 : -22  open: 1
# 0:00:30.249868

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open    high  \
# 172  172  2004      3   31 2004-03-31 22:00:00        2  0.75258  0.7669
# 173  173  2004      4    1 2004-04-01 22:00:00        3  0.76611  0.7691
#
#          low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 172  0.75251  0.76628  ...  0.746894    0.759214       172.0         172.0
# 173  0.75934  0.76635  ...  0.760019    0.773216       173.0          -1.0
#
#      closeprice  tpcloseprice  slindex  slprice  profit  profit1
# 172    0.759214        0.7669     -1.0 -1.00000  66.339        1
# 173    0.760019       -1.0000    173.0  0.75934 -60.906       -1
#
# [2 rows x 127 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [10]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    runstats35(alltrades,'35',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'40',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'45',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'50',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'60',atrperiod,sl,tp,tsl)
    runstats35(alltrades,'80',atrperiod,sl,tp,tsl)

    
#     stats1 = runstats28(alltrades,'30',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'40',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'50',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'60',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'80',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'100',atrperiod,sl,tp,tsl)

#     stats1 = runstats28(alltrades,'120',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'140',atrperiod,sl,tp,tsl)
#     stats1 = runstats28(alltrades,'160',atrperiod,sl,tp,tsl)
# Out:
# ma_35_2003_2021_1_atr10atr_prev_ma35SMAvs3_prevx1
# allexecs:  59535
# ____progress:   1.0918
# elapsed:        0:00:30.026937
# last run:       0:00:30.026937
# remaining:      0:45:20.209516
# estimated end:  2021-12-19 12:08:50.876734
# ____progress:   2.1433
# elapsed:        0:01:00.060726
# last run:       0:00:30.033789
# remaining:      0:45:42.224009
# estimated end:  2021-12-19 12:09:42.926015
# ____progress:   3.1847
# elapsed:        0:01:30.082863
# last run:       0:00:30.021138
# remaining:      0:45:38.547542
# estimated end:  2021-12-19 12:10:09.270686
# ____progress:   4.2412
# elapsed:        0:02:00.082974
# last run:       0:00:30.000111
# remaining:      0:45:11.259544
# estimated end:  2021-12-19 12:10:11.982799
# ____progress:   5.2876
# elapsed:        0:02:30.085972
# last run:       0:00:30.002998
# remaining:      0:44:48.341075
# estimated end:  2021-12-19 12:10:19.067328
# ____progress:   6.3425
# elapsed:        0:03:00.092913
# last run:       0:00:30.006941
# remaining:      0:44:19.375195
# estimated end:  2021-12-19 12:10:20.108389
# ____progress:   7.3956
# elapsed:        0:03:30.098851
# last run:       0:00:30.005938
# remaining:      0:43:50.744913
# estimated end:  2021-12-19 12:10:21.484045
# ____progress:   8.4354
# elapsed:        0:04:00.127575
# last run:       0:00:30.028724
# remaining:      0:43:26.546096
# estimated end:  2021-12-19 12:10:27.314953
# ____progress:   9.4264
# elapsed:        0:04:30.144327
# last run:       0:00:30.016752
# remaining:      0:43:15.686483
# estimated end:  2021-12-19 12:10:46.472092
# ____progress:   10.4846
# elapsed:        0:05:00.157328
# last run:       0:00:30.012000
# remaining:      0:42:42.685755
# estimated end:  2021-12-19 12:10:43.483364
# ____progress:   11.5411
# elapsed:        0:05:30.167956
# last run:       0:00:30.010628
# remaining:      0:42:10.630947
# estimated end:  2021-12-19 12:10:41.440189
# ____progress:   12.6077
# elapsed:        0:06:00.189032
# last run:       0:00:30.020071
# remaining:      0:41:36.705988
# estimated end:  2021-12-19 12:10:37.535301
# ____progress:   13.6558
# elapsed:        0:06:30.212172
# last run:       0:00:30.023140
# remaining:      0:41:07.264047
# estimated end:  2021-12-19 12:10:38.116500
# ____progress:   14.7107
# elapsed:        0:07:00.218245
# last run:       0:00:30.006073
# remaining:      0:40:36.334988
# estimated end:  2021-12-19 12:10:37.193514
# ____progress:   15.6950
# elapsed:        0:07:30.243018
# last run:       0:00:30.024773
# remaining:      0:40:18.466108
# estimated end:  2021-12-19 12:10:49.349407
# ____progress:   16.7985
# elapsed:        0:08:00.253960
# last run:       0:00:30.010942
# remaining:      0:39:38.652100
# estimated end:  2021-12-19 12:10:39.547342
# ____progress:   17.9088
# elapsed:        0:08:30.279062
# last run:       0:00:30.025102
# remaining:      0:38:59.042262
# estimated end:  2021-12-19 12:10:29.961605
# ____progress:   19.0392
# elapsed:        0:09:00.307043
# last run:       0:00:30.027981
# remaining:      0:38:17.556195
# estimated end:  2021-12-19 12:10:18.503519
# ____progress:   20.1478
# elapsed:        0:09:30.308074
# last run:       0:00:30.001031
# remaining:      0:37:40.312283
# estimated end:  2021-12-19 12:10:11.260638
# ____progress:   21.2732
# elapsed:        0:10:00.332946
# last run:       0:00:30.024872
# remaining:      0:37:01.682209
# estimated end:  2021-12-19 12:10:02.656437
# ____progress:   22.3919
# elapsed:        0:10:30.350166
# last run:       0:00:30.017220
# remaining:      0:36:24.734759
# estimated end:  2021-12-19 12:09:55.725206
# ____progress:   23.5089
# elapsed:        0:11:00.384071
# last run:       0:00:30.033905
# remaining:      0:35:48.701787
# estimated end:  2021-12-19 12:09:49.726139
# ____progress:   24.6309
# elapsed:        0:11:30.402619
# last run:       0:00:30.018548
# remaining:      0:35:12.592466
# estimated end:  2021-12-19 12:09:43.636364
# ____progress:   25.7512
# elapsed:        0:12:00.416352
# last run:       0:00:30.013733
# remaining:      0:34:37.182468
# estimated end:  2021-12-19 12:09:38.239101
# ____progress:   26.8716
# elapsed:        0:12:30.419804
# last run:       0:00:30.003452
# remaining:      0:34:02.194462
# estimated end:  2021-12-19 12:09:33.255547
# ____progress:   27.9936
# elapsed:        0:13:00.453654
# last run:       0:00:30.033850
# remaining:      0:33:27.516362
# estimated end:  2021-12-19 12:09:28.610297
# ____progress:   29.1022
# elapsed:        0:13:30.480049
# last run:       0:00:30.026395
# remaining:      0:32:54.463372
# estimated end:  2021-12-19 12:09:25.583702
# ____progress:   30.2175
# elapsed:        0:14:00.496972
# last run:       0:00:30.016923
# remaining:      0:32:20.992035
# estimated end:  2021-12-19 12:09:22.129288
# ____progress:   31.3328
# elapsed:        0:14:30.527964
# last run:       0:00:30.030992
# remaining:      0:31:47.797453
# estimated end:  2021-12-19 12:09:18.965698
# ____progress:   32.4381
# elapsed:        0:15:00.559175
# last run:       0:00:30.031211
# remaining:      0:31:15.683083
# estimated end:  2021-12-19 12:09:16.883538
# ____progress:   33.5601
# elapsed:        0:15:30.574016
# last run:       0:00:30.013842
# remaining:      0:30:42.285045
# estimated end:  2021-12-19 12:09:13.499342
# ____progress:   34.6653
# elapsed:        0:16:00.585489
# last run:       0:00:30.011473
# remaining:      0:30:10.441601
# estimated end:  2021-12-19 12:09:11.667371
# ____progress:   35.7739
# elapsed:        0:16:30.588749
# last run:       0:00:30.003260
# remaining:      0:29:38.436567
# estimated end:  2021-12-19 12:09:09.665597
# ____progress:   36.8825
# elapsed:        0:17:00.610205
# last run:       0:00:30.021456
# remaining:      0:29:06.583007
# estimated end:  2021-12-19 12:09:07.833493
# ____progress:   37.9793
# elapsed:        0:17:30.633691
# last run:       0:00:30.023486
# remaining:      0:28:35.695830
# estimated end:  2021-12-19 12:09:06.970803
# ____progress:   39.1047
# elapsed:        0:18:00.662147
# last run:       0:00:30.027455
# remaining:      0:28:02.845474
# estimated end:  2021-12-19 12:09:04.147902
# ____progress:   40.2116
# elapsed:        0:18:30.667914
# last run:       0:00:30.005767
# remaining:      0:27:31.387820
# estimated end:  2021-12-19 12:09:02.696015
# ____progress:   41.3253
# elapsed:        0:19:00.685907
# last run:       0:00:30.017993
# remaining:      0:26:59.576479
# estimated end:  2021-12-19 12:09:00.902667
# ____progress:   42.4305
# elapsed:        0:19:30.727461
# last run:       0:00:30.041554
# remaining:      0:26:28.437235
# estimated end:  2021-12-19 12:08:59.805981
# ____progress:   43.5341
# elapsed:        0:20:00.750748
# last run:       0:00:30.023287
# remaining:      0:25:57.436449
# estimated end:  2021-12-19 12:08:58.827478
# ____progress:   44.6326
# elapsed:        0:20:30.774219
# last run:       0:00:30.023471
# remaining:      0:25:26.795521
# estimated end:  2021-12-19 12:08:58.210021
# ____progress:   45.7378
# elapsed:        0:21:00.816217
# last run:       0:00:30.041998
# remaining:      0:24:55.801245
# estimated end:  2021-12-19 12:08:57.257743
# ____progress:   46.8464
# elapsed:        0:21:30.821996
# last run:       0:00:30.005779
# remaining:      0:24:24.613197
# estimated end:  2021-12-19 12:08:56.075474
# ____progress:   47.9600
# elapsed:        0:22:00.868030
# last run:       0:00:30.046034
# remaining:      0:23:53.234102
# estimated end:  2021-12-19 12:08:54.743414
# ____progress:   49.0703
# elapsed:        0:22:30.904996
# last run:       0:00:30.036966
# remaining:      0:23:22.094557
# estimated end:  2021-12-19 12:08:53.639834
# ____progress:   50.0563
# elapsed:        0:23:00.941626
# last run:       0:00:30.036630
# remaining:      0:22:57.836929
# estimated end:  2021-12-19 12:08:59.418836
# ____progress:   50.9767
# elapsed:        0:23:30.962937
# last run:       0:00:30.021311
# remaining:      0:22:36.893614
# estimated end:  2021-12-19 12:09:08.496832
# ____progress:   51.9661
# elapsed:        0:24:01.005843
# last run:       0:00:30.042906
# remaining:      0:22:11.968585
# estimated end:  2021-12-19 12:09:13.614709
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_456/3059067120.py in <module>
#       4 for i in [10]:
#       5     atrperiod = 'atr'+str(i)+'atr_prev'
# ----> 6     runstats35(alltrades,'35',atrperiod,sl,tp,tsl)
#       7     runstats35(alltrades,'40',atrperiod,sl,tp,tsl)
#       8     runstats35(alltrades,'45',atrperiod,sl,tp,tsl)
#
# ~\notebooks\wm\tradestats.py in runstats35(alltrades, ma1, atrperiod, sl, tp, tsl)
#    3056 def runstats35(alltrades,ma1,atrperiod,sl,tp,tsl):
#    3057     ma2 = '3'
# -> 3058     runstats_ma_v35(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#    3059     ma2 = '5'
#    3060     runstats_ma_v35(alltrades,'ma'+ma1+'SMAdiffseq_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiffseq_prev', 'ma'+ma2+'SMAdiffdiff_prev', atrperiod,sl,tp,tsl,'x1')
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v35(alltrades, a, b, sv, aa, bb, atr, sl, tp, tsl, ff)
#    3080     conf['filename'] =    'ma_35_2003_2021_1_'+atr+'_'+sv+ff
#    3081     print(conf['filename'])
# -> 3082     stathyperparams2(alltrades,params,conf)
#    3083     return
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1226     seq['lastrun'] = datetime.now()
#    1227     stats = stats.values.tolist()
# -> 1228     stats = execstats2_r(trades,stats,params,seq)
#    1229     stats = pd.DataFrame(stats)
#    1230
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1297             for ifrom in params[key][1]:
#    1298                 seq[key] = [imode,ifrom]
# -> 1299                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1300         elif (imode == 3):
#    1301             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1304                 if (ito>ifrom):
#    1305                     seq[key] = [imode,ifrom,ito]
# -> 1306                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1307
#    1308     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1284                     if (ito>ifrom):
#    1285                         seq[key] = [imode,ifrom,ito]
# -> 1286                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1287         elif (imode == 1):
#    1288             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1307
#    1308     else:
# -> 1309         stats = execstats2(trades,stats,params,seq)
#    1310     return stats
#    1311
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1316     else:
#    1317         seq['execs'] = seq['execs'] + 1
# -> 1318         df = calculatestats2(trades,params,seq)
#    1319         if (not df is None):
#    1320             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1341     timedump('1')
#    1342
# -> 1343     stats0 = trades.copy()
#    1344 #     for kk in params.keys():
#    1345 #         imode = seq[kk][0]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5931         dtype: object
#    5932         """
# -> 5933         data = self._mgr.copy(deep=deep)
#    5934         self._clear_item_cache()
#    5935         return self._constructor(data).__finalize__(self, method="copy")
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in copy(self, deep)
#     597             new_axes = list(self.axes)
#     598
# --> 599         res = self.apply("copy", deep=deep)
#     600         res.axes = new_axes
#     601
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in copy(self, deep)
#     648         values = self.values
#     649         if deep:
# --> 650             values = values.copy()
#     651         return self.make_block_same_class(values)
#     652
#
# KeyboardInterrupt:
