# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
# import graphviz

# %%
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()

maKey  = [5,30,40,50,60,80,100,120,130,140,160]
atrKey = [20]
# srsKey = [0]
dictList = []
colFeat = []
keyList = []
maDict   = ma(prices, maKey)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 

endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0:00:00.195311

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]
# Out:
# C:\Users\piotrek\AppData\Local\Temp/ipykernel_1488/3922565144.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
masterFrame.tail(5)
# Out:
#         id  year  month  day                date  weekday     open     high  \
# 4748  4748  2021     10   18 2021-10-18 21:00:00        0  0.74146  0.74370
# 4749  4749  2021     10   19 2021-10-19 21:00:00        1  0.74080  0.74851
# 4750  4750  2021     10   20 2021-10-20 21:00:00        2  0.74715  0.75222
# 4751  4751  2021     10   21 2021-10-21 21:00:00        3  0.75128  0.75460
# 4752  4752  2021     10   22 2021-10-22 21:00:00        4  0.74654  0.75118
#
#           low    close  ...  ma160SMA10  ma160SMA20  ma160SMA_prev  \
# 4748  0.73781  0.74102  ...    0.734858    0.729893       0.752543
# 4749  0.74074  0.74715  ...    0.736676    0.731104       0.752395
# 4750  0.74647  0.75144  ...    0.739118    0.732456       0.752243
# 4751  0.74581  0.74655  ...    0.740678    0.733326       0.752106
# 4752  0.74533  0.74631  ...    0.742257    0.734352       0.751905
#
#       ma160SMAdiff_prev  ma160SMAdiff2_prev  ma160SMAdiffdiff_prev  \
# 4748          -0.000165           -0.000357               0.000026
# 4749          -0.000148           -0.000313               0.000017
# 4750          -0.000152           -0.000300              -0.000004
# 4751          -0.000137           -0.000289               0.000015
# 4752          -0.000201           -0.000338              -0.000064
#
#       ma160SMAvs5_prev  ma160SMAvs10_prev  ma160SMAvs20_prev  atr20atr_prev
# 4748         -0.014523          -0.018927          -0.023451       0.006553
# 4749         -0.013045          -0.017537          -0.022502       0.006606
# 4750         -0.010427          -0.015567          -0.021139       0.006687
# 4751         -0.007544          -0.012988          -0.019650       0.006611
# 4752         -0.006325          -0.011227          -0.018580       0.006588
#
# [5 rows x 122 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
starttime = datetime.now()
atrperiod = 'atr20atr_prev'
sl = [0.4,0.5,0.6,0.7,0.8,0.9]
tp = [0.6,0.7,0.8,0.9,1,1.1,1.3,1.5]
tsl = []
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.3 : 0.6 : -5
# 0.3 : 0.7 : -7
# 0.3 : 0.8 : -9
# 0.3 : 0.9 : -10
# 0.3 : 1 : -11
# 0.3 : 1.1 : -11
# 0.3 : 1.2 : -13
# 0.3 : 1.3 : -14
# 0.3 : 1.4 : -15
# 0.3 : 1.5 : -15
# 0.4 : 0.6 : -8
# 0.4 : 0.7 : -8
# 0.4 : 0.8 : -9
# 0.4 : 0.9 : -10
# 0.4 : 1 : -11
# 0.4 : 1.1 : -12
# 0.4 : 1.2 : -17
# 0.4 : 1.3 : -18
# 0.4 : 1.4 : -19
# 0.4 : 1.5 : -19
# 0.5 : 0.6 : -12
# 0.5 : 0.7 : -12
# 0.5 : 0.8 : -13
# 0.5 : 0.9 : -13
# 0.5 : 1 : -14
# 0.5 : 1.1 : -16
# 0.5 : 1.2 : -17
# 0.5 : 1.3 : -28
# 0.5 : 1.4 : -29
# 0.5 : 1.5 : -29
# 0.6 : 0.6 : -12
# 0.6 : 0.7 : -12
# 0.6 : 0.8 : -13
# 0.6 : 0.9 : -13
# 0.6 : 1 : -14
# 0.6 : 1.1 : -16
# 0.6 : 1.2 : -17
# 0.6 : 1.3 : -28
# 0.6 : 1.4 : -29
# 0.6 : 1.5 : -29
# 0.7 : 0.6 : -12
# 0.7 : 0.7 : -12
# 0.7 : 0.8 : -13
# 0.7 : 0.9 : -17
# 0.7 : 1 : -17
# 0.7 : 1.1 : -17
# 0.7 : 1.2 : -21
# 0.7 : 1.3 : -28
# 0.7 : 1.4 : -29
# 0.7 : 1.5 : -29
# 0.8 : 0.6 : -12
# 0.8 : 0.7 : -12
# 0.8 : 0.8 : -13
# 0.8 : 0.9 : -17
# 0.8 : 1 : -17
# 0.8 : 1.1 : -21
# 0.8 : 1.2 : -26
# 0.8 : 1.3 : -28
# 0.8 : 1.4 : -31
# 0.8 : 1.5 : -31
# 0.9 : 0.6 : -13
# 0.9 : 0.7 : -16
# 0.9 : 0.8 : -16
# 0.9 : 0.9 : -17
# 0.9 : 1 : -20
# 0.9 : 1.1 : -21
# 0.9 : 1.2 : -26
# 0.9 : 1.3 : -28
# 0.9 : 1.4 : -31
# 0.9 : 1.5 : -31
# 0:01:06.375457

# %%
importlib.reload(tradestats)
from tradestats import *
trades = cleartrades_brut(alltrades.copy(),True)
# trades,alltrades = preparetrades(masterFrame,[-1,1],[5],[13],[0.002],True)

# %%
#____________________________________________________________________________________________________________________
#
#
alltrades.head(2)
# Out:
#       id  year  month  day                date  weekday     open     high  \
# 162  162  2004      3   17 2004-03-17 22:00:00        2  0.74192  0.74355
# 163  163  2004      3   18 2004-03-18 22:00:00        3  0.74107  0.75308
#
#         low    close  ...  stoploss  takeprofit  closeindex  tpcloseindex  \
# 162  0.7359  0.74081  ...  0.738161    0.749439       162.0          -1.0
# 163  0.7392  0.75065  ...  0.737396    0.748417       163.0         163.0
#
#      closeprice  tpcloseprice  slindex  slprice   profit  profit1
# 162    0.738161      -1.00000    162.0   0.7359 -37.5945       -1
# 163    0.748417       0.75308     -1.0  -1.0000  73.4730        1
#
# [2 rows x 139 columns]

# %%
importlib.reload(tradestats)
from tradestats import *
def runstats(ma1,atrperiod,sl,tp,tsl):
    ma2 = '5'
    stats1 = runstats_ma_v24(alltrades,'ma'+ma1+'SMAdiff_prev','ma'+ma1+'SMAdiffdiff_prev','ma'+ma1+'SMAdiff2_prev','ma'+ma1+'SMAvs'+ma2+'_prev','ma'+ma2+'SMAdiff_prev','ma'+ma2+'SMAdiffdiff_prev',atrperiod,sl,tp,tsl)
    ma2 = '10'
    stats1 = runstats_ma_v24(alltrades,'ma'+ma1+'SMAdiff_prev','ma'+ma1+'SMAdiffdiff_prev','ma'+ma1+'SMAdiff2_prev','ma'+ma1+'SMAvs'+ma2+'_prev','ma'+ma2+'SMAdiff_prev','ma'+ma2+'SMAdiffdiff_prev',atrperiod,sl,tp,tsl)
    ma2 = '20'
    stats1 = runstats_ma_v24(alltrades,'ma'+ma1+'SMAdiff_prev','ma'+ma1+'SMAdiffdiff_prev','ma'+ma1+'SMAdiff2_prev','ma'+ma1+'SMAvs'+ma2+'_prev','ma'+ma2+'SMAdiff_prev','ma'+ma2+'SMAdiffdiff_prev',atrperiod,sl,tp,tsl)
    return stats1

# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
#     stats1 = runstats('30',atrperiod,sl,tp,tsl)
#     stats1 = runstats('40',atrperiod,sl,tp,tsl)
#     stats1 = runstats('50',atrperiod,sl,tp,tsl)
#     stats1 = runstats('60',atrperiod,sl,tp,tsl)
#     stats1 = runstats('80',atrperiod,sl,tp,tsl)
#     stats1 = runstats('100',atrperiod,sl,tp,tsl)
    stats1 = runstats('120',atrperiod,sl,tp,tsl)
    stats1 = runstats('140',atrperiod,sl,tp,tsl)
    stats1 = runstats('160',atrperiod,sl,tp,tsl)
# Out:
# ma_24_2003_2021_1_atr20atr_prev_ma120SMAvs5_prev
# allexecs:  51030
# ____progress:   0.2685
# elapsed:        0:00:30.216909
# last run:       0:00:30.216909
# remaining:      3:07:05.030290
# estimated end:  2021-12-05 19:59:11.140391
# ____progress:   0.5526
# elapsed:        0:01:00.327150
# last run:       0:00:30.110241
# remaining:      3:00:56.319887
# estimated end:  2021-12-05 19:53:32.540229
# ____progress:   0.8230
# elapsed:        0:01:30.515432
# last run:       0:00:30.189284
# remaining:      3:01:47.109556
# estimated end:  2021-12-05 19:54:53.519182
# ____progress:   1.0994
# elapsed:        0:02:00.724977
# last run:       0:00:30.208543
# remaining:      3:01:00.728813
# estimated end:  2021-12-05 19:54:37.346982
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1488/804790374.py in <module>
#      19 #     stats1 = runstats('80',atrperiod,sl,tp,tsl)
#      20 #     stats1 = runstats('100',atrperiod,sl,tp,tsl)
# ---> 21     stats1 = runstats('120',atrperiod,sl,tp,tsl)
#      22     stats1 = runstats('140',atrperiod,sl,tp,tsl)
#      23     stats1 = runstats('160',atrperiod,sl,tp,tsl)
#
# ~\AppData\Local\Temp/ipykernel_1488/804790374.py in runstats(ma1, atrperiod, sl, tp, tsl)
#       3 def runstats(ma1,atrperiod,sl,tp,tsl):
#       4     ma2 = '5'
# ----> 5     stats1 = runstats_ma_v24(alltrades,'ma'+ma1+'SMAdiff_prev','ma'+ma1+'SMAdiffdiff_prev','ma'+ma1+'SMAdiff2_prev','ma'+ma1+'SMAvs'+ma2+'_prev','ma'+ma2+'SMAdiff_prev','ma'+ma2+'SMAdiffdiff_prev',atrperiod,sl,tp,tsl)
#       6     ma2 = '10'
#       7     stats1 = runstats_ma_v24(alltrades,'ma'+ma1+'SMAdiff_prev','ma'+ma1+'SMAdiffdiff_prev','ma'+ma1+'SMAdiff2_prev','ma'+ma1+'SMAvs'+ma2+'_prev','ma'+ma2+'SMAdiff_prev','ma'+ma2+'SMAdiffdiff_prev',atrperiod,sl,tp,tsl)
#
# ~\notebooks\wm\tradestats.py in runstats_ma_v24(alltrades, a, b, c, d, aa, bb, atr, sl, tp, tsl)
#    2492     conf['filename'] =    'ma_24_2003_2021_1_'+atr+'_'+d
#    2493     print(conf['filename'])
# -> 2494     stats = stathyperparams2(alltrades,params,conf)
#    2495     return stats
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1050     seq['lastrun'] = datetime.now()
#    1051
# -> 1052     stats = execstats2_r(trades,stats,params,seq)
#    1053     stats.to_csv(sep=';',path_or_buf='../Data/stats00.csv',date_format="%Y-%m-%d",index = False,na_rep='')
#    1054     if (len(stats)==0):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1114             for ifrom in params[key][1]:
#    1115                 seq[key] = [imode,ifrom]
# -> 1116                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1117         elif (imode == 3):
#    1118             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1114             for ifrom in params[key][1]:
#    1115                 seq[key] = [imode,ifrom]
# -> 1116                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1117         elif (imode == 3):
#    1118             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1114             for ifrom in params[key][1]:
#    1115                 seq[key] = [imode,ifrom]
# -> 1116                 stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1117         elif (imode == 3):
#    1118             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1121                 if (ito>ifrom):
#    1122                     seq[key] = [imode,ifrom,ito]
# -> 1123                     stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1124
#    1125     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1101                     if (ito>ifrom):
#    1102                         seq[key] = [imode,ifrom,ito]
# -> 1103                         stats = execstats2_r(trades,stats,params,seq,cursor+1)
#    1104         elif (imode == 1):
#    1105             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, cursor)
#    1124
#    1125     else:
# -> 1126         stats = execstats2(trades,stats,params,seq)
#    1127     return stats
#    1128
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq)
#    1133     else:
#    1134         seq['execs'] = seq['execs'] + 1
# -> 1135         df = calculatestats2(trades,params,seq)
#    1136         if (not df is None):
#    1137             seq['locs'] = seq['locs'] + 1
#
# ~\notebooks\wm\tradestats.py in calculatestats2(trades, params, seq)
#    1162             stats0 = stats0[stats0[kk].isin(seq[kk][1])]
#    1163         elif (imode == 2):
# -> 1164             stats0 = stats0[stats0[kk]==seq[kk][1]]
#    1165
#    1166     pr_c = len(stats0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3502         key = check_bool_indexer(self.index, key)
#    3503         indexer = key.nonzero()[0]
# -> 3504         return self._take_with_is_copy(indexer, axis=0)
#    3505
#    3506     def _getitem_multilevel(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3613         self._consolidate_inplace()
#    3614
# -> 3615         new_data = self._mgr.take(
#    3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify)
#     863
#     864         new_labels = self.axes[axis].take(indexer)
# --> 865         return self.reindex_indexer(
#     866             new_axis=new_labels,
#     867             indexer=indexer,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice)
#     678             )
#     679         else:
# --> 680             new_blocks = [
#     681                 blk.take_nd(
#     682                     indexer,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     679         else:
#     680             new_blocks = [
# --> 681                 blk.take_nd(
#     682                     indexer,
#     683                     axis=1,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1142             allow_fill = True
#    1143
# -> 1144         new_values = algos.take_nd(
#    1145             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1146         )
#
# ~\anaconda3\lib\site-packages\pandas\core\array_algos\take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     106
#     107     arr = np.asarray(arr)
# --> 108     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     109
#     110
#
# KeyboardInterrupt:
