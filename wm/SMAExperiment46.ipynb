# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
    # !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
    # !git fetch --all
    # !git reset --hard origin/master

# %%
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
    # %cd "/content/gdrive/My Drive/Projects"
#     !git clone https://github.com/ai357060/modelF.git
    import sys
    root_dir="/content/gdrive/My Drive/Projects/modelF"
    sys.path.append(root_dir)
    # %cd "/content/gdrive/My Drive/Projects/modelF/wm"
#     !git pull

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime
importlib.reload(tradestats)
from tradestats import *

# %%
prices = loaddata_1D('AUDUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')
# prices = loaddata_1D('EURUSD_Candlestick_1_D_BID_03.08.2003-24.10.2021.csv')

# %%
len(prices)
# Out:
# 4753

# %%
dictList = []
colFeat = []
keyList = []

maKey  = [3,5,7,30,35,40,45,60,80,100,120,140,160]
atrKey = [20]
# srsKey = [0]
rsiKey = [15]

maDict   = ma(prices, maKey,3,5,7)
atrDict  = atr(prices, atrKey)
# srsDict  = srs(prices, srsKey)
rsiDict = rsi(prices,rsiKey)

dictList.append(maDict.df); colFeat.append('ma'); keyList.append(maKey) 
dictList.append(atrDict.df); colFeat.append('atr'); keyList.append(atrKey) 
# dictList.append(srsDict.df); colFeat.append('srs'); keyList.append(srsKey) 
dictList.append(rsiDict.df); colFeat.append('rsi'); keyList.append(rsiKey) 

tt = [1]
sl = [0.6,0.65,0.7,0.75,0.8,0.85,0.9]
tp = [0.7,0.75,0.8,0.85,0.9]
tsl = [0,0.3,0.5,0.7]
atrperiod = 'atr20atr_prev'
savetrades = False

# %%
# prices.dropna(inplace=True)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['id','year','month','day','date','weekday','open','high','low','close','volume']] = prices[['id','year','month','day','date','weekday','open','high','low','close','volume']]

# %%
for i in range(0,len(dictList)):#iteracja po funkcjach
    for j in keyList[i]: #iteracja po okresach
        for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
            colID = colFeat[i] + str(j) + k
            masterFrame[colID] = dictList[i][j][k]
# Out:
# C:\Users\piotrek\AppData\Local\Temp/ipykernel_10236/3922565144.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   masterFrame[colID] = dictList[i][j][k]

# %%
# masterFrame.to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='')

# %%
masterFrame = masterFrame.dropna()

# %%
starttime = datetime.now()
# alltrades = preparetrades_brut_tsl(masterFrame,[1],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],[0.001,0.002,0.003,0.004,0.005,0.006],2015,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],2003,2021)
# alltrades = preparetrades_brut_tp(masterFrame,[-1,1],[0.5],[0.9],2020,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.3,0.4,0.5,0.6,0.7,0.8,0.9],[0.6,0.7,0.8,0.9,1,1.1,1.2,1.3,1.4,1.5],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[1],[1,1.2,1.4,1.6,1.8,2,2.2],[1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2],2003,2021,atrperiod)
alltrades = preparetrades_brut_tsl(masterFrame,tt,sl,tp+[100],tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tsl(masterFrame,[1],sl,tp,tsl,2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01],[0.006,0.007,0.008,0.009,0.01,0.011,0.012,0.013,0.014,0.015],2003,2021,atrperiod)
# alltrades = preparetrades_brut_tp(masterFrame,[-1],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],[0.003,0.004,0.005,0.006,0.007,0.008,0.01,0.012,0.014],2003,2021,atrperiod)
endtime = datetime.now()
print(str(endtime - starttime))
# Out:
# 0.6 : 0.7 : 0 : -12  open: 0
# 0.6 : 0.7 : 0.3 : -15  open: 1
# 0.6 : 0.7 : 0.5 : -16  open: 1
# 0.6 : 0.7 : 0.7 : -28  open: 1
# 0.6 : 0.75 : 0 : -13  open: 1
# 0.6 : 0.75 : 0.3 : -15  open: 1
# 0.6 : 0.75 : 0.5 : -16  open: 1
# 0.6 : 0.75 : 0.7 : -28  open: 1
# 0.6 : 0.8 : 0 : -13  open: 1
# 0.6 : 0.8 : 0.3 : -15  open: 2
# 0.6 : 0.8 : 0.5 : -16  open: 2
# 0.6 : 0.8 : 0.7 : -28  open: 2
# 0.6 : 0.85 : 0 : -13  open: 1
# 0.6 : 0.85 : 0.3 : -15  open: 2
# 0.6 : 0.85 : 0.5 : -16  open: 2
# 0.6 : 0.85 : 0.7 : -28  open: 2
# 0.6 : 0.9 : 0 : -13  open: 1
# 0.6 : 0.9 : 0.3 : -15  open: 2
# 0.6 : 0.9 : 0.5 : -16  open: 2
# 0.6 : 0.9 : 0.7 : -28  open: 2
# 0.6 : 100 : 0 : -22  open: 1
# 0.65 : 0.7 : 0 : -12  open: 0
# 0.65 : 0.7 : 0.3 : -15  open: 1
prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiff_prev', 'ma'+ma2+'SMAdiffdiff_prev', 'rsi15rsidiff1n_prev', 'rsi15rsi_prev', atrperiod,sl,tp,tsl,'x1',fxs)

    return stats

def runstats_ma_v46(alltrades,a,b,sv,aa,bb,aaa,bbb,atr='atr140atr_prev',sl=[],tp=[],tsl=[],ff='',fxs=[]):
    conf   = {}
    params = {}
    
    params['tradetype'] = [2,[1]]
    params['sl'] =        [2,sl]
    params['tp'] =        [2,tp]
    params['tsl'] =       [2,tsl]
    params[atr]  =        [3,[-1000],[0.015]]
    params[a]    =        [0,[-1000,0,1000],[-1000,0,1000]]
    params[b]    =        [0,[-1000,0,1000],[-1000,0,1000]]
    params[sv]    =       [0,[-1000,0,1000],[-1000,0,1000]]
    params[aa]   =        [0,[-1000,0,1000],[-1000,0,1000]]
    params[bb]   =        [0,[-1000,0,1000],[-1000,0,1000]]
    params[aaa]    =      [3,[-1000,-1000,-1000,-1000,-1000],[-4,-3,-2,-1,0]]
    params[bbb]    =      [0,[0,30,40,50,60,70],[30,40,50,60,70,100]]

    conf['filename'] =    'ma_46_2003_2021_1_'+atr+'_'+sv+ff
    if (fxs!=[]):
        conf['fxs'] = fxs
    print(conf['filename'])
    stats = stathyperparams2(alltrades,params,conf)
    return stats

# %%
# runstats45(alltrades,'30',atrperiod,sl,tp,tsl,5)
runstats46(alltrades,'35',atrperiod,sl,tp,tsl,3)
# runstats45(alltrades,'40',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'45',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'60',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'80',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'100',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'120',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'140',atrperiod,sl,tp,tsl,5)
# runstats45(alltrades,'160',atrperiod,sl,tp,tsl,5)
    

# [3,5,7,30,35,40,45,60,80,100,120,140,160]
# Out:
# ma_46_2003_2021_1_atr20atr_prev_ma35SMAvs3_prevx1
# allexecs:  1190700
# ____progress:   2.02 %
# elapsed:        0:00:30.000768
# last run:       0:00:30.000768
# remaining:      0:24:12.543928
# estimated end:  2021-12-31 17:50:41.794304
# ____progress:   4.07 %
# elapsed:        0:01:00.000965
# last run:       0:00:30.000197
# remaining:      0:23:35.030500
# estimated end:  2021-12-31 17:50:34.281073
# ____progress:   6.12 %
# elapsed:        0:01:30.002951
# last run:       0:00:30.001986
# remaining:      0:22:59.460688
# estimated end:  2021-12-31 17:50:28.714246
# ____progress:   8.19 %
# elapsed:        0:02:00.003904
# last run:       0:00:30.000953
# remaining:      0:22:25.084926
# estimated end:  2021-12-31 17:50:24.338438
# ____progress:   10.22 %
# elapsed:        0:02:30.005397
# last run:       0:00:30.001493
# remaining:      0:21:57.318151
# estimated end:  2021-12-31 17:50:26.573156
# ____progress:   12.22 %
# elapsed:        0:03:00.005904
# last run:       0:00:30.000507
# remaining:      0:21:32.526832
# estimated end:  2021-12-31 17:50:31.782344
# ____progress:   14.27 %
# elapsed:        0:03:30.007906
# last run:       0:00:30.002002
# remaining:      0:21:01.171794
# estimated end:  2021-12-31 17:50:30.429308
# ____progress:   16.32 %
# elapsed:        0:04:00.009853
# last run:       0:00:30.001947
# remaining:      0:20:30.216880
# estimated end:  2021-12-31 17:50:29.476341
# ____progress:   18.37 %
# elapsed:        0:04:30.011746
# last run:       0:00:30.001893
# remaining:      0:20:00.025318
# estimated end:  2021-12-31 17:50:29.286672
# ____progress:   20.39 %
# elapsed:        0:05:00.012737
# last run:       0:00:30.001991
# remaining:      0:19:31.387862
# estimated end:  2021-12-31 17:50:30.651207
# ____progress:   22.46 %
# elapsed:        0:05:30.014754
# last run:       0:00:30.001017
# remaining:      0:18:59.649601
# estimated end:  2021-12-31 17:50:28.913963
# ____progress:   24.50 %
# elapsed:        0:06:00.015151
# last run:       0:00:30.000397
# remaining:      0:18:29.265719
# estimated end:  2021-12-31 17:50:28.531478
# ____progress:   26.56 %
# elapsed:        0:06:30.016795
# last run:       0:00:30.001644
# remaining:      0:17:58.266350
# estimated end:  2021-12-31 17:50:27.532753
# ____progress:   28.57 %
# elapsed:        0:07:00.017638
# last run:       0:00:30.000843
# remaining:      0:17:30.221284
# estimated end:  2021-12-31 17:50:29.488530
# ____progress:   30.54 %
# elapsed:        0:07:30.018982
# last run:       0:00:30.001344
# remaining:      0:17:03.718272
# estimated end:  2021-12-31 17:50:32.986862
# ____progress:   32.56 %
# elapsed:        0:08:00.019214
# last run:       0:00:30.000232
# remaining:      0:16:34.248572
# estimated end:  2021-12-31 17:50:33.517394
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10236/2967111657.py in <module>
#       1 # runstats45(alltrades,'30',atrperiod,sl,tp,tsl,5)
# ----> 2 runstats46(alltrades,'35',atrperiod,sl,tp,tsl,3)
#       3 # runstats45(alltrades,'40',atrperiod,sl,tp,tsl,5)
#       4 # runstats45(alltrades,'45',atrperiod,sl,tp,tsl,5)
#       5 # runstats45(alltrades,'60',atrperiod,sl,tp,tsl,5)
#
# ~\AppData\Local\Temp/ipykernel_10236/2125921212.py in runstats46(alltrades, ma1, atrperiod, sl, tp, tsl, ma2, fxs)
#       1 def runstats46(alltrades,ma1,atrperiod,sl,tp,tsl,ma2 = 5,fxs=[]):
#       2     ma2=str(ma2)
# ----> 3     stats = runstats_ma_v46(alltrades,'ma'+ma1+'SMAdiff_prev', 'ma'+ma1+'SMAdiffdiff_prev', 'ma'+ma1+'SMAvs'+ma2+'_prev', 'ma'+ma2+'SMAdiff_prev', 'ma'+ma2+'SMAdiffdiff_prev', 'rsi15rsidiff1n_prev', 'rsi15rsi_prev', atrperiod,sl,tp,tsl,'x1',fxs)
#       4
#       5     return stats
#
# ~\AppData\Local\Temp/ipykernel_10236/2125921212.py in runstats_ma_v46(alltrades, a, b, sv, aa, bb, aaa, bbb, atr, sl, tp, tsl, ff, fxs)
#      26         conf['fxs'] = fxs
#      27     print(conf['filename'])
# ---> 28     stats = stathyperparams2(alltrades,params,conf)
#      29     return stats
#
# ~\notebooks\wm\tradestats.py in stathyperparams2(trades, params, conf)
#    1261     fx = {}
#    1262     stats = []
# -> 1263     stats = execstats2_r(trades,stats,params,seq,fx)
#    1264     stats = pd.DataFrame(stats)
#    1265
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1349                 else:
#    1350                     trades1 = trades
# -> 1351                 stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1352         elif (imode == 3):
#    1353             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1349                 else:
#    1350                     trades1 = trades
# -> 1351                 stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1352         elif (imode == 3):
#    1353             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1349                 else:
#    1350                     trades1 = trades
# -> 1351                 stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1352         elif (imode == 3):
#    1353             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1349                 else:
#    1350                     trades1 = trades
# -> 1351                 stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1352         elif (imode == 3):
#    1353             for ii in range(0, len(params[key][1])):
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1361                     else:
#    1362                         trades1 = trades
# -> 1363                     stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1364
#    1365     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1361                     else:
#    1362                         trades1 = trades
# -> 1363                     stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1364
#    1365     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1326                         else:
#    1327                             trades1 = trades
# -> 1328                         stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1329         elif (imode == 1):
#    1330             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1326                         else:
#    1327                             trades1 = trades
# -> 1328                         stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1329         elif (imode == 1):
#    1330             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1326                         else:
#    1327                             trades1 = trades
# -> 1328                         stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1329         elif (imode == 1):
#    1330             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1326                         else:
#    1327                             trades1 = trades
# -> 1328                         stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1329         elif (imode == 1):
#    1330             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1361                     else:
#    1362                         trades1 = trades
# -> 1363                     stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1364
#    1365     else:
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1326                         else:
#    1327                             trades1 = trades
# -> 1328                         stats = execstats2_r(trades1,stats,params,seq,fx,cursor+1)
#    1329         elif (imode == 1):
#    1330             froms = params[key][1]
#
# ~\notebooks\wm\tradestats.py in execstats2_r(trades, stats, params, seq, fx, cursor)
#    1364
#    1365     else:
# -> 1366         stats = execstats2(trades,stats,params,seq,fx)
#    1367     return stats
#    1368
#
# ~\notebooks\wm\tradestats.py in execstats2(trades, stats, params, seq, fx)
#    1379     else:
#    1380         seq['execs'] = seq['execs'] + 1
# -> 1381         df = calculatestats2(trades,params,seq,fx)
#    1382         if (not df is None):
#    1383             timedump('10')
#
# ~\notebooks\wm\tradestats.py in calculatestats2(stats0, params, seq, fx)
#    1417     if ((pr_c>=seq['mintrades']) and (pr_maxp>0)):
#    1418         pr_c_u = len(stats0[stats0.profit>=0])
# -> 1419         pr_c_d = len(stats0[stats0.profit<0])
#    1420 #         yearmonth = stats0.groupby(['year','month'])['profit'].sum().reset_index()
#    1421 #         monthsup = len(yearmonth[yearmonth.profit>0])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3502         key = check_bool_indexer(self.index, key)
#    3503         indexer = key.nonzero()[0]
# -> 3504         return self._take_with_is_copy(indexer, axis=0)
#    3505
#    3506     def _getitem_multilevel(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3613         self._consolidate_inplace()
#    3614
# -> 3615         new_data = self._mgr.take(
#    3616             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3617         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify)
#     862         indexer = maybe_convert_indices(indexer, n, verify=verify)
#     863
# --> 864         new_labels = self.axes[axis].take(indexer)
#     865         return self.reindex_indexer(
#     866             new_axis=new_labels,
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#     959         # Note: we discard fill_value and use self._na_value, only relevant
#     960         #  in the case where allow_fill is True and fill_value is not None
# --> 961         taken = algos.take(
#     962             self._values, indices, allow_fill=allow_fill, fill_value=self._na_value
#     963         )
#
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in take(arr, indices, axis, allow_fill, fill_value)
#    1514     else:
#    1515         # NumPy style
# -> 1516         result = arr.take(indices, axis=axis)
#    1517     return result
#    1518
#
# KeyboardInterrupt:

# %%
importlib.reload(tradestats)
from tradestats import *
# for i in [10,14,20,30,40]:
for i in [20]:
    atrperiod = 'atr'+str(i)+'atr_prev'
    fxs=runstats45(alltrades,'40',atrperiod,sl,tp,tsl,5,[2078507])

sub = calcandplot(alltrades,fxs)

# %%
fxs = [
'{"tradetype": [2, 1], "sl": [2, 0.65], "tp": [2, 0.75], "tsl": [2, 0], "atr20atr_prev": [3, -1000, 0.015], "ma40SMAdiffseq_prev": [0, 3, 1000], "ma40SMAvs5_prev": [0, 0, 1000], "ma5SMAdiffdiff_prev": [0, -1000, 0], "rsi15rsidiffseq_prev": [0, -5, 3], "rsi15rsi_prev": [0, 30, 100]}'
]    
sub = calcandplot(alltrades,fxs)
