# %%
#mount
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
root_dir="/content/gdrive/My Drive/Projects/flower"
sys.path.append(root_dir)

# %cd "/content/gdrive/My Drive/Projects/flower/wm"
# Out:
# /content/gdrive/My Drive/Projects/flower/wm

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime
import sys

# %%
importlib.reload(tradestats)
from tradestats import *
from tradestats import rose

snake([],[],onlytry=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-672d8bfb868c> in <cell line: 1>()
# ----> 1 importlib.reload(tradestats)
#       2 from tradestats import *
#       3 from tradestats import rose
#       4
#       5 snake([],[],onlytry=1)
#
# NameError: name 'importlib' is not defined

# %%
importlib.reload(tradestats)
from tradestats import *
from tradestats import rose

periods = [2]
dictList = []
colFeat = []
keyList = []
roseDict   = rose(prices, periods,history,ignore,entry_buy,entry_sell,0,False)
dictList.append(roseDict.df); colFeat.append('rose'); keyList.append(periods)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['year','date','close']] = prices[['year','date','close']]

for i in range(0,len(dictList)):#iteracja po funkcjach
  for j in keyList[i]: #iteracja po okresach
    for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
        colID = colFeat[i] + str(j) + k
        masterFrame[colID] = dictList[i][j][k]
masterFrame = masterFrame.dropna()
# Out:
# mbk_w.csv
# 100%

# %%
 masterFrame
# Out:
#       year       date  rose2profit1  rose2profit0       close  rose2rose  \
# 0     1992 1992-10-05           1.0           0.0    3.919933          1
# 1     1992 1992-10-12           1.0           0.0    3.600065         -1
# 2     1992 1992-10-19           1.0           0.0    4.339995          2
# 3     1992 1992-10-26           1.0           0.0    4.220030          0
# 4     1992 1992-11-02           1.0           0.0    4.200015          0
# ...    ...        ...           ...           ...         ...        ...
# 1633  2024 2024-01-22           1.0           0.0  506.800000          0
# 1634  2024 2024-01-29           1.0           0.0  559.200000          2
# 1635  2024 2024-02-05           1.0           0.0  546.400000          0
# 1636  2024 2024-02-12           1.0           0.0  629.400000          2
# 1637  2024 2024-02-19           1.0           0.0  658.800000          2
#
#      rose2uptick_date  rose2uptick_close  rose2uptick_diff rose2downtick_date  \
# 0          1900-01-01           0.000000          0.000000         1900-01-01
# 1          1900-01-01           0.000000          0.000000         1900-01-01
# 2          1900-01-01           0.000000          0.000000         1900-01-01
# 3          1992-10-19           4.339995         -0.027642         1900-01-01
# 4          1992-10-19           4.339995         -0.032254         1900-01-01
# ...               ...                ...               ...                ...
# 1633       2023-11-27         573.800000         -0.116765         2024-01-15
# 1634       2023-11-27         573.800000         -0.025444         2024-01-15
# 1635       2024-01-29         559.200000         -0.022890         2024-01-15
# 1636       1900-01-01           0.000000          0.000000         2024-01-15
# 1637       1900-01-01           0.000000          0.000000         2024-01-15
#
#       ...  rose2open_trade  rose2close_trade  rose2open_trade_date  \
# 0     ...              0.0               0.0            1900-01-01
# 1     ...              0.0               0.0            1900-01-01
# 2     ...              0.0               0.0            1900-01-01
# 3     ...              0.0               0.0            1900-01-01
# 4     ...              0.0               0.0            1900-01-01
# ...   ...              ...               ...                   ...
# 1633  ...              0.0               0.0            1900-01-01
# 1634  ...            559.2               0.0            1900-01-01
# 1635  ...              0.0               0.0            1900-01-01
# 1636  ...              0.0               0.0            1900-01-01
# 1637  ...              0.0               0.0            1900-01-01
#
#       rose2open_trade_close  rose2climate  rose2profit  rose2rosehigh  \
# 0                       0.0             1          0.0       0.000000
# 1                       0.0             1          0.0       0.000000
# 2                       0.0             1          0.0       4.339995
# 3                       0.0             1          0.0       0.000000
# 4                       0.0             1          0.0       0.000000
# ...                     ...           ...          ...            ...
# 1633                    0.0             1          0.0       0.000000
# 1634                    0.0             1          0.0     559.200000
# 1635                    0.0             1          0.0       0.000000
# 1636                    0.0             1          0.0     629.400000
# 1637                    0.0             1          0.0     658.800000
#
#       rose2roselow  rose2climateU  rose2climateD
# 0              0.0       3.919933            0.0
# 1              0.0       3.600065            0.0
# 2              0.0       4.339995            0.0
# 3              0.0       4.220030            0.0
# 4              0.0       4.200015            0.0
# ...            ...            ...            ...
# 1633           0.0     506.800000            0.0
# 1634           0.0     559.200000            0.0
# 1635           0.0     546.400000            0.0
# 1636           0.0     629.400000            0.0
# 1637           0.0     658.800000            0.0
#
# [1638 rows x 31 columns]

# %%
masterFrame.round(2).to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='', decimal=',')
