# %%
#mount
import os
cwd = os.getcwd()
if cwd[0:2] != "C:":
    from google.colab import drive
    drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
root_dir="/content/gdrive/My Drive/Projects/flower"
sys.path.append(root_dir)

# %cd "/content/gdrive/My Drive/Projects/flower/wm"
# Out:
# /content/gdrive/My Drive/Projects/flower/wm

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import datetime as dt
import importlib
import tradestats
import pandas as pd
from datetime import datetime
import sys

# %%
importlib.reload(tradestats)
from tradestats import *
from tradestats import snake

snake([],[],1)
# Out:
# 1

# %%
importlib.reload(tradestats)
from tradestats import *
from tradestats import snake

filenames = ['wig_w.csv','wig20_w.csv','mbk_w.csv','alr_w.csv','pko_w.csv','peo_w.csv','pkn_w.csv','san_w.csv','pzu_w.csv','pge_w.csv','pco_w.csv','opl_w.csv','lpp_w.csv','kru_w.csv','kgh_w.csv','jsw_w.csv','kty_w.csv','dnp_w.csv','cps_w.csv','cdr_w.csv','acp_w.csv','ale_w.csv']

for filename in filenames:
  print('')
  print(filename)
  if '_d.'in filename:
    prices = loaddata_1D(filename)
  elif '_w.'in filename:
    prices = loaddata_1W(filename)
  else:
    print('file timeframe not supported')
    continue

periods = [2]
dictList = []
colFeat = []
keyList = []
snakeDict   = snake(prices, periods,0)
dictList.append(snakeDict.df); colFeat.append('snake'); keyList.append(periods)
masterFrame = pd.DataFrame(index=prices.index)
masterFrame[['year','date','close']] = prices[['year','date','close']]

for i in range(0,len(dictList)):#iteracja po funkcjach
  for j in keyList[i]: #iteracja po okresach
    for k in list(dictList[i][j]): #iteracja po kolumnach danej funkcji w okresie
        colID = colFeat[i] + str(j) + k
        masterFrame[colID] = dictList[i][j][k]
masterFrame = masterFrame.dropna()
# Out:
# wig_w.csv
#
# wig20_w.csv
#
# mbk_w.csv
#
# alr_w.csv
#
# pko_w.csv
#
# peo_w.csv
#
# pkn_w.csv
#
# san_w.csv
#
# pzu_w.csv
#
# pge_w.csv
#
# pco_w.csv
#
# opl_w.csv
#
# lpp_w.csv
#
# kru_w.csv
#
# kgh_w.csv
#
# jsw_w.csv
#
# kty_w.csv
#
# dnp_w.csv
#
# cps_w.csv
#
# cdr_w.csv
#
# acp_w.csv
#
# ale_w.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-7ec8903e8921> in <cell line: 22>()
#      20 colFeat = []
#      21 keyList = []
# ---> 22 roseDict   = rose(prices, periods,0)
#      23 dictList.append(roseDict.df); colFeat.append('rose'); keyList.append(periods)
#      24 masterFrame = pd.DataFrame(index=prices.index)
#
# /content/gdrive/MyDrive/Projects/flower/wm/tradestats.py in rose(prices, periods, history, ignore, entry_buy_perc, entry_sell_perc, onlytry, takeclimate)
#     320     df = df.drop(columns='id')
#     321     df = df.drop(columns='date')
# --> 322     df = df.drop(columns='rose_prev')
#     323     df = df.drop(columns='date_prev')
#     324     df = df.drop(columns='close_prev')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['rose_prev'] not found in axis"

# %%
prices
# Out:
#      index       date   open    high     low   close     volume  year  month  \
# 0        0 2020-10-12  65.00  90.300  60.000  81.450  116768921  2020     10
# 1        1 2020-10-19  81.45  89.000  79.800  89.000   44995806  2020     10
# 2        2 2020-10-26  89.00  98.780  80.000  80.450   14612760  2020     10
# 3        3 2020-11-02  81.20  93.000  81.180  92.130   11033578  2020     11
# 4        4 2020-11-09  94.00  95.300  74.700  75.880   17674176  2020     11
# ..     ...        ...    ...     ...     ...     ...        ...   ...    ...
# 171    171 2024-01-22  31.30  31.525  29.755  30.220    7980727  2024      1
# 172    172 2024-01-29  30.20  31.570  29.850  30.410    7322049  2024      1
# 173    173 2024-02-05  30.60  31.795  30.250  31.665    7840829  2024      2
# 174    174 2024-02-12  31.70  32.735  30.785  31.800    7501505  2024      2
# 175    175 2024-02-19  31.80  33.940  31.140  32.870    9539350  2024      2
#
#      week  day  weekday   id
# 0    <NA>   12        0    0
# 1    <NA>   19        0    1
# 2    <NA>   26        0    2
# 3    <NA>    2        0    3
# 4    <NA>    9        0    4
# ..    ...  ...      ...  ...
# 171  <NA>   22        0  171
# 172  <NA>   29        0  172
# 173  <NA>    5        0  173
# 174  <NA>   12        0  174
# 175  <NA>   19        0  175
#
# [176 rows x 13 columns]

# %%
masterFrame.round(2).to_csv(sep=';',path_or_buf='../Data/masterFrame.csv',date_format="%Y-%m-%d",index = False,na_rep='', decimal=',')
